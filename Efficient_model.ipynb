# %%
import os
import gc
import time
import shutil
import random
import warnings
import typing as tp
from pathlib import Path
from contextlib import contextmanager

import yaml
from joblib import delayed, Parallel

import cv2
import librosa
import audioread
import soundfile as sf

import numpy as np
import pandas as pd

from sklearn.metrics import f1_score
from sklearn.model_selection import StratifiedKFold

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.utils.data as data
import resnest.torch as resnest_torch

import pytorch_pfn_extras as ppe
from pytorch_pfn_extras.training import extensions as ppe_extensions
import pytorch_pfn_extras.training.extensions as extensions

import IPython.display as ipd
import matplotlib.pyplot as plt
import librosa.display


pd.options.display.max_rows = 500
pd.options.display.max_columns = 500


from efficientnet_pytorch import model as enet

from ignite.engine import Events, create_supervised_trainer, create_supervised_evaluator
from ignite.metrics import Accuracy, Loss


TRAIN_AUDIO_DIR = Path( "small_data")
TRAIN_RESAMPLED_AUDIO_DIRS = Path( "small_data")
train=pd.read_csv('train_final.csv')

# play audio
def play_audio(file):
    x , sr = librosa.load(file)
    return ipd.Audio(file)


# Define utilities
def set_seed(seed: int = 42):
    random.seed(seed)
    np.random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)  # type: ignore
#     torch.backends.cudnn.deterministic = True  # type: ignore
#     torch.backends.cudnn.benchmark = True  # type: ignore
    

@contextmanager
def timer(name: str) -> None:
    """Timer Util"""
    t0 = time.time()
    print("[{}] start".format(name))
    yield
    print("[{}] done in {:.0f} s".format(name, time.time() - t0))
    
# set strings
settings_str = """
globals:
  seed: 1213
  device: cpu
  num_epochs: 20
  output_dir: training_output_v4/
  use_fold: 0
  target_sr: 32000

dataset:
  name: SpectrogramDataset
  params:
    img_size: 224
    melspectrogram_parameters:
      n_mels: 128
      fmin: 20
      fmax: 16000
    
split:
  name: StratifiedKFold
  params:
    n_splits: 5
    random_state: 42
    shuffle: True

loader:
  train:
    batch_size: 20
    shuffle: True
    num_workers: 0
    pin_memory: True
    drop_last: True
  val:
    batch_size: 20
    shuffle: False
    num_workers: 0
    pin_memory: True
    drop_last: False

model:
  name: resnest50_fast_1s1x64d
  params:
    pretrained: True
    n_classes: 5

loss:
  name: CrossEntropyLoss
  params: {}

optimizer:
  name: Adam
  params:
    lr: 0.001

scheduler:
  name: CosineAnnealingLR
  params:
    T_max: 10
"""
settings = yaml.safe_load(settings_str)



# read data

def train_audio_dir(file_path):
    return Path(file_path)



# preprocess audio data
def resample(ebird_code: str,filename: str, target_sr: int):    
    audio_dir = TRAIN_AUDIO_DIR
    resample_dir = TRAIN_RESAMPLED_DIR
    ebird_dir = resample_dir / ebird_code
    
    try:
        y, _ = librosa.load(
            audio_dir / ebird_code / filename,
            sr=target_sr, mono=True, res_type="kaiser_fast")

        filename = filename.replace(".mp3", ".wav")
        sf.write(ebird_dir / filename, y, samplerate=target_sr)
    except Exception as e:
        print(e)
        with open("skipped.txt", "a") as f:
            file_path = str(audio_dir / ebird_code / filename)
            f.write(file_path + "\n")

keys = set(train.ebird_code)
values = np.arange(0, len(keys))
BIRD_CODE  = dict(zip(sorted(keys), values))
INV_BIRD_CODE = {v: k for k, v in BIRD_CODE.items()}

PERIOD = 5

def mono_to_color(
    X: np.ndarray, mean=None, std=None,
    norm_max=None, norm_min=None, eps=1e-6
):
    # Stack X as [X,X,X]
    X = np.stack([X, X, X], axis=-1)

    # Standardize
    mean = mean or X.mean()
    X = X - mean
    std = std or X.std()
    Xstd = X / (std + eps)
    _min, _max = Xstd.min(), Xstd.max()
    norm_max = norm_max or _max
    norm_min = norm_min or _min
    if (_max - _min) > eps:
        # Normalize to [0, 255]
        V = Xstd
        V[V < norm_min] = norm_min
        V[V > norm_max] = norm_max
        V = 255 * (V - norm_min) / (norm_max - norm_min)
        V = V.astype(np.uint8)
    else:
        # Just zero
        V = np.zeros_like(Xstd, dtype=np.uint8)
    return V

class SpectrogramDataset(data.Dataset):
    def __init__(
        self,
        file_list: tp.List[tp.List[str]], img_size=224,
        waveform_transforms=None, spectrogram_transforms=None, melspectrogram_parameters={}
    ):
        self.file_list = file_list  # list of list: [file_path, ebird_code]
        self.img_size = img_size
        self.waveform_transforms = waveform_transforms
        self.spectrogram_transforms = spectrogram_transforms
        self.melspectrogram_parameters = melspectrogram_parameters

    def __len__(self):
        return len(self.file_list)

    def __getitem__(self, idx: int):
        wav_path, ebird_code = self.file_list[idx]

        y, sr = sf.read(wav_path)

        if self.waveform_transforms:
            y = self.waveform_transforms(y)
        else:
            len_y = len(y)
            effective_length = sr * PERIOD
            if len_y < effective_length:
                new_y = np.zeros(effective_length, dtype=y.dtype)
                start = np.random.randint(effective_length - len_y)
                new_y[start:start + len_y] = y
                y = new_y.astype(np.float32)
            elif len_y > effective_length:
                start = np.random.randint(len_y - effective_length)
                y = y[start:start + effective_length].astype(np.float32)
            else:
                y = y.astype(np.float32)

        melspec = librosa.feature.melspectrogram(y, sr=sr, **self.melspectrogram_parameters)
        melspec = librosa.power_to_db(melspec).astype(np.float32)

        if self.spectrogram_transforms:
            melspec = self.spectrogram_transforms(melspec)
        else:
            pass

        image = mono_to_color(melspec)
        height, width, _ = image.shape
#         image = cv2.resize(image,(self.img_size, self.img_size))
        image = cv2.resize(image,(378, self.img_size))
        image = np.moveaxis(image, 2, 0)
        image = (image / 255.0).astype(np.float32)

#         labels = np.zeros(len(BIRD_CODE), dtype="i")
        labels = np.zeros(len(BIRD_CODE), dtype="f")
        labels[BIRD_CODE[ebird_code]] = 1

        return image, labels
    
# Train Utility

def get_loaders_for_training(
    args_dataset: tp.Dict, args_loader: tp.Dict,
    train_file_list: tp.List[str], val_file_list: tp.List[str]
):
    # # make dataset
    train_dataset = SpectrogramDataset(train_file_list, **args_dataset)
    val_dataset = SpectrogramDataset(val_file_list, **args_dataset)
    # # make dataloader
    train_loader = data.DataLoader(train_dataset, **args_loader["train"])
    val_loader = data.DataLoader(val_dataset, **args_loader["val"])
    return train_loader, val_loader


pretrained_model = {
    'efficientnet-b2': 'efficientnet-b2-27687264.pth'
}

enet_type = 'efficientnet-b2'

device = torch.device('cpu')


class enetv2(nn.Module):
    def __init__(self, backbone):
        super(enetv2, self).__init__()
        self.enet = enet.EfficientNet.from_name(backbone)
        self.enet.load_state_dict(torch.load(pretrained_model[backbone]))

        self.myfc = nn.Sequential(
        nn.Linear(self.enet._fc.in_features,512), nn.ReLU(), nn.Dropout(p=0.2),
        nn.Linear(512, 5))
        
        self.enet._fc = nn.Identity()

    def extract(self, x):
        return self.enet(x)

    def forward(self, x):
        x = self.extract(x)
#         print(x.shape)
        x = self.myfc(x)
        return x
    
def get_model(args: tp.Dict):
    model =enetv2(enet_type)
    model = model.to(device)
        
    return model

def train_loop(
    manager, args, model, device,
    train_loader, optimizer, scheduler, loss_func
):
    """Run minibatch training loop"""
    while not manager.stop_trigger:
        model.train()
        for batch_idx, (data, target) in enumerate(train_loader):
            with manager.run_iteration():
                data, target = data.to(device), target.to(device)
                target = torch.argmax(target, axis=-1)
                optimizer.zero_grad()
                output = model(data)
                loss = loss_func(output, target) # Loss: CrossEntropy
                ppe.reporting.report({'train/loss': loss.item()})
                loss.backward()
                optimizer.step()
        scheduler.step()  # <- call at the end of each epoch
        

def eval_for_batch(
    args, model, device,
    data, target, loss_func, eval_func_dict={}
):
    """
    Run evaliation for valid
    
    This function is applied to each batch of val loader.
    """
    model.eval()
    data, target = data.to(device), target.to(device)
    output = model(data)
    # Final result will be average of averages of the same size
    target = torch.argmax(target, axis=-1) # From 2D to 1D
    val_loss = loss_func(output, target).item()
    ppe.reporting.report({'val/loss': val_loss})
    
    for eval_name, eval_func in eval_func_dict.items():
        eval_value = eval_func(output, target).item()
        ppe.reporting.report({"val/{}".format(eval_aame): eval_value})
        
    print(output.shape, target.shape)


def set_extensions(
    manager, args, model, device, test_loader, optimizer, evaluator,
    loss_func, eval_func_dict={}
):
    """set extensions for PPE"""
        
    my_extensions = [
        # # observe, report
        ppe_extensions.observe_lr(optimizer=optimizer),
        # ppe_extensions.ParameterStatistics(model, prefix='model'),
        # ppe_extensions.VariableStatisticsPlot(model),
        ppe_extensions.LogReport(),
        ppe_extensions.IgniteEvaluator(
            evaluator, test_loader, model, progress_bar=True),
        ppe_extensions.PlotReport(['train/loss', 'val/loss'], 'epoch', filename='loss.png'),
        ppe_extensions.PlotReport(['lr',], 'epoch', filename='lr.png'),
        ppe_extensions.PrintReport([
            'epoch', 'iteration', 'lr', 'train/loss', 'val/loss','val/acc', "elapsed_time"]),
#         ppe_extensions.ProgressBar(update_interval=100),

        # # evaluation
        (
            ppe_extensions.Evaluator(
                test_loader, model,
                eval_func=lambda data, target:
                    eval_for_batch(args, model, device, data, target, loss_func, eval_func_dict),
                progress_bar=True),
            (1, "epoch"),
        ),
        # # save model snapshot.
        (
            ppe_extensions.snapshot(
                target=model, filename="snapshot_epoch_{.updater.epoch}.pth"),
            ppe.training.triggers.MinValueTrigger(key="val/loss", trigger=(1, 'epoch'))
        ),
    ]
           
    # # set extensions to manager
    for ext in my_extensions:
        if isinstance(ext, tuple):
            manager.extend(ext[0], trigger=ext[1])
        else:
            manager.extend(ext)
        
    return manager
    

# Train
# get wav file path

train=train.rename(columns={'filename':'resampled_filename'})
train.resampled_filename=[filename.replace(".mp3", ".wav") for filename in train.resampled_filename]

tmp_list = []
for ebird_d  in TRAIN_RESAMPLED_AUDIO_DIRS.iterdir():
    if os.path.split(ebird_d)[1]=='.DS_Store':
        continue

    for wav_f in ebird_d.iterdir():
        tmp_list.append([ebird_d.name, wav_f.name, wav_f.as_posix()])

train_wav_path_exist = pd.DataFrame(
    tmp_list, columns=["ebird_code", "resampled_filename", "file_path"])

del tmp_list

train_all = pd.merge(train, train_wav_path_exist, on=["ebird_code", "resampled_filename"], how="inner")

# split data
skf = StratifiedKFold(**settings["split"]["params"])

train_all["fold"] = -1
for fold_id, (train_index, val_index) in enumerate(skf.split(train_all, train_all["ebird_code"])):
    train_all.iloc[val_index, -1] = fold_id
    
# # check the propotion
fold_proportion = pd.pivot_table(train_all, index="ebird_code", columns="fold", values="xc_id", aggfunc=len)

use_fold = settings["globals"]["use_fold"]
train_file_list = train_all.query("fold != @use_fold")[["file_path", "ebird_code"]].values.tolist()
val_file_list = train_all.query("fold == @use_fold")[["file_path", "ebird_code"]].values.tolist()


# running training 

set_seed(settings["globals"]["seed"])
device = torch.device(settings["globals"]["device"])
output_dir = Path(settings["globals"]["output_dir"])

# # # get loader
train_loader, val_loader = get_loaders_for_training(
    settings["dataset"]["params"], settings["loader"], train_file_list, val_file_list)

# # # get model
model = get_model(settings["model"])
model = model.to(device)

# # # get optimizer
optimizer = getattr(
    torch.optim, settings["optimizer"]["name"]
)(model.parameters(), **settings["optimizer"]["params"])

# # # get scheduler
scheduler = getattr(
    torch.optim.lr_scheduler, settings["scheduler"]["name"]
)(optimizer, **settings["scheduler"]["params"])

# # # get loss
loss_func = getattr(nn, settings["loss"]["name"])(**settings["loss"]["params"])

# get evaluator
evaluator = create_supervised_evaluator(
    model,
    metrics={'acc': Accuracy(is_multilabel=True)},
    device=device,
    output_transform=lambda x,y,y_pred: (torch.FloatTensor(y_pred.shape).zero_().scatter_(0,  torch.argmax(y_pred, 0,keepdim=True), 1),
                                         y))

      
# # # create training manager
trigger = None


manager = ppe.training.ExtensionsManager(
    model, optimizer, settings["globals"]["num_epochs"],
    iters_per_epoch=len(train_loader),
    stop_trigger=trigger,
    out_dir=output_dir
)

# # # set manager extensions
manager = set_extensions(
    manager, settings, model, device,
    val_loader, optimizer,evaluator ,loss_func,
)

# Train loop

# # runtraining with lr = 0.001

train_loop(
    manager, settings, model, device,
    train_loader, optimizer, scheduler, loss_func)
# Out:
# /home/jovyan/my-conda-envs/deep_final/lib/python3.6/site-packages/librosa/filters.py:239: UserWarning: Empty filters detected in mel frequency basis. Some channels will produce empty responses. Try increasing your sampling rate (and fmax) or reducing n_mels.
#   "Empty filters detected in mel frequency basis. "
# epoch       iteration   lr          train/loss  val/loss    val/acc     elapsed_time
# validation [#####.............................................] 10.00%
#          1 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [##########........................................] 20.00%
#          2 iterations
#    0.95574 iters/sec. Estimated time to finish: 0:00:08.370472.
# validation [###############...................................] 30.00%
#          3 iterations
#    0.92157 iters/sec. Estimated time to finish: 0:00:07.595703.
# validation [####################..............................] 40.00%
#          4 iterations
#    0.92508 iters/sec. Estimated time to finish: 0:00:06.485934.
# validation [#########################.........................] 50.00%
#          5 iterations
#    0.93216 iters/sec. Estimated time to finish: 0:00:05.363884.
# validation [##############################....................] 60.00%
#          6 iterations
#    0.94147 iters/sec. Estimated time to finish: 0:00:04.248660.
# validation [###################################...............] 70.00%
#          7 iterations
#     0.9497 iters/sec. Estimated time to finish: 0:00:03.158882.
# validation [########################################..........] 80.00%
#          8 iterations
#    0.94396 iters/sec. Estimated time to finish: 0:00:02.118739.
# validation [#############################################.....] 90.00%
#          9 iterations
#    0.95066 iters/sec. Estimated time to finish: 0:00:01.051901.
# validation [##################################################] 100.00%
#         10 iterations
#    0.95612 iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [#####.............................................] 10.00%
#          1 iterations
#    0.96499 iters/sec. Estimated time to finish: 0:00:09.326560.
# torch.Size([20, 5]) torch.Size([20])
# validation [##########........................................] 20.00%
#          2 iterations
#    0.91683 iters/sec. Estimated time to finish: 0:00:08.725729.
# torch.Size([20, 5]) torch.Size([20])
# validation [###############...................................] 30.00%
#          3 iterations
#    0.92888 iters/sec. Estimated time to finish: 0:00:07.535948.
# torch.Size([20, 5]) torch.Size([20])
# validation [####################..............................] 40.00%
#          4 iterations
#    0.93174 iters/sec. Estimated time to finish: 0:00:06.439564.
# torch.Size([20, 5]) torch.Size([20])
# validation [#########################.........................] 50.00%
#          5 iterations
#    0.94208 iters/sec. Estimated time to finish: 0:00:05.307410.
# torch.Size([20, 5]) torch.Size([20])
# validation [##############################....................] 60.00%
#          6 iterations
#     0.9478 iters/sec. Estimated time to finish: 0:00:04.220293.
# torch.Size([20, 5]) torch.Size([20])
# validation [###################################...............] 70.00%
#          7 iterations
#    0.94404 iters/sec. Estimated time to finish: 0:00:03.177829.
# torch.Size([20, 5]) torch.Size([20])
# validation [########################################..........] 80.00%
#          8 iterations
#    0.94984 iters/sec. Estimated time to finish: 0:00:02.105617.
# torch.Size([20, 5]) torch.Size([20])
# validation [#############################################.....] 90.00%
#          9 iterations
#     0.9557 iters/sec. Estimated time to finish: 0:00:01.046349.
# 1           40          0.001       1.05055     1.15357     0.08        169.16
# validation [#####.............................................] 10.00%
#          1 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [##########........................................] 20.00%
#          2 iterations
#    0.95254 iters/sec. Estimated time to finish: 0:00:08.398619.
# validation [###############...................................] 30.00%
#          3 iterations
#    0.92106 iters/sec. Estimated time to finish: 0:00:07.599976.
# validation [####################..............................] 40.00%
#          4 iterations
#    0.93245 iters/sec. Estimated time to finish: 0:00:06.434677.
# validation [#########################.........................] 50.00%
#          5 iterations
#    0.93805 iters/sec. Estimated time to finish: 0:00:05.330207.
# validation [##############################....................] 60.00%
#          6 iterations
#    0.94598 iters/sec. Estimated time to finish: 0:00:04.228403.
# validation [###################################...............] 70.00%
#          7 iterations
#    0.95307 iters/sec. Estimated time to finish: 0:00:03.147730.
# validation [########################################..........] 80.00%
#          8 iterations
#    0.94842 iters/sec. Estimated time to finish: 0:00:02.108760.
# validation [#############################################.....] 90.00%
#          9 iterations
#    0.95396 iters/sec. Estimated time to finish: 0:00:01.048259.
# validation [##################################################] 100.00%
#         10 iterations
#    0.95857 iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [#####.............................................] 10.00%
#          1 iterations
#    0.96599 iters/sec. Estimated time to finish: 0:00:09.316831.
# torch.Size([20, 5]) torch.Size([20])
# validation [##########........................................] 20.00%
#          2 iterations
#    0.92887 iters/sec. Estimated time to finish: 0:00:08.612638.
# torch.Size([20, 5]) torch.Size([20])
# validation [###############...................................] 30.00%
#          3 iterations
#    0.93678 iters/sec. Estimated time to finish: 0:00:07.472426.
# torch.Size([20, 5]) torch.Size([20])
# validation [####################..............................] 40.00%
#          4 iterations
#     0.9424 iters/sec. Estimated time to finish: 0:00:06.366727.
# torch.Size([20, 5]) torch.Size([20])
# validation [#########################.........................] 50.00%
#          5 iterations
#     0.9468 iters/sec. Estimated time to finish: 0:00:05.280940.
# torch.Size([20, 5]) torch.Size([20])
# validation [##############################....................] 60.00%
#          6 iterations
#    0.95492 iters/sec. Estimated time to finish: 0:00:04.188853.
# torch.Size([20, 5]) torch.Size([20])
# validation [###################################...............] 70.00%
#          7 iterations
#    0.94976 iters/sec. Estimated time to finish: 0:00:03.158709.
# torch.Size([20, 5]) torch.Size([20])
# validation [########################################..........] 80.00%
#          8 iterations
#    0.95516 iters/sec. Estimated time to finish: 0:00:02.093886.
# torch.Size([20, 5]) torch.Size([20])
# validation [#############################################.....] 90.00%
#          9 iterations
#    0.95785 iters/sec. Estimated time to finish: 0:00:01.044003.
# 2           80          0.000975528  0.710258    1.52437     0.085       335.734
# validation [#####.............................................] 10.00%
#          1 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [##########........................................] 20.00%
#          2 iterations
#    0.81372 iters/sec. Estimated time to finish: 0:00:09.831450.
# validation [###############...................................] 30.00%
#          3 iterations
#    0.78513 iters/sec. Estimated time to finish: 0:00:08.915707.
# validation [####################..............................] 40.00%
#          4 iterations
#    0.79027 iters/sec. Estimated time to finish: 0:00:07.592314.
# validation [#########################.........................] 50.00%
#          5 iterations
#    0.79311 iters/sec. Estimated time to finish: 0:00:06.304303.
# validation [##############################....................] 60.00%
#          6 iterations
#    0.79956 iters/sec. Estimated time to finish: 0:00:05.002767.
# validation [###################################...............] 70.00%
#          7 iterations
#    0.80471 iters/sec. Estimated time to finish: 0:00:03.728059.
# validation [########################################..........] 80.00%
#          8 iterations
#    0.80108 iters/sec. Estimated time to finish: 0:00:02.496619.
# validation [#############################################.....] 90.00%
#          9 iterations
#    0.80293 iters/sec. Estimated time to finish: 0:00:01.245435.
# validation [##################################################] 100.00%
#         10 iterations
#    0.80599 iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [#####.............................................] 10.00%
#          1 iterations
#    0.80206 iters/sec. Estimated time to finish: 0:00:11.221163.
# torch.Size([20, 5]) torch.Size([20])
# validation [##########........................................] 20.00%
#          2 iterations
#    0.77993 iters/sec. Estimated time to finish: 0:00:10.257386.
# torch.Size([20, 5]) torch.Size([20])
# validation [###############...................................] 30.00%
#          3 iterations
#    0.78704 iters/sec. Estimated time to finish: 0:00:08.894105.
# torch.Size([20, 5]) torch.Size([20])
# validation [####################..............................] 40.00%
#          4 iterations
#    0.78998 iters/sec. Estimated time to finish: 0:00:07.595116.
# torch.Size([20, 5]) torch.Size([20])
# validation [#########################.........................] 50.00%
#          5 iterations
#    0.79701 iters/sec. Estimated time to finish: 0:00:06.273447.
# torch.Size([20, 5]) torch.Size([20])
# validation [##############################....................] 60.00%
#          6 iterations
#    0.80128 iters/sec. Estimated time to finish: 0:00:04.992014.
# torch.Size([20, 5]) torch.Size([20])
# validation [###################################...............] 70.00%
#          7 iterations
#    0.79789 iters/sec. Estimated time to finish: 0:00:03.759935.
# torch.Size([20, 5]) torch.Size([20])
# validation [########################################..........] 80.00%
#          8 iterations
#    0.80146 iters/sec. Estimated time to finish: 0:00:02.495445.
# torch.Size([20, 5]) torch.Size([20])
# validation [#############################################.....] 90.00%
#          9 iterations
#    0.80445 iters/sec. Estimated time to finish: 0:00:01.243087.
# 3           120         0.000904508  0.665613    1.34118     0.07        506.211
# validation [#####.............................................] 10.00%
#          1 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [##########........................................] 20.00%
#          2 iterations
#    0.98576 iters/sec. Estimated time to finish: 0:00:08.115534.
# validation [###############...................................] 30.00%
#          3 iterations
#    0.94404 iters/sec. Estimated time to finish: 0:00:07.414927.
# validation [####################..............................] 40.00%
#          4 iterations
#    0.95264 iters/sec. Estimated time to finish: 0:00:06.298268.
# validation [#########################.........................] 50.00%
#          5 iterations
#    0.95454 iters/sec. Estimated time to finish: 0:00:05.238110.
# validation [##############################....................] 60.00%
#          6 iterations
#    0.96204 iters/sec. Estimated time to finish: 0:00:04.157818.
# validation [###################################...............] 70.00%
#          7 iterations
#    0.97114 iters/sec. Estimated time to finish: 0:00:03.089166.
# validation [########################################..........] 80.00%
#          8 iterations
#    0.96448 iters/sec. Estimated time to finish: 0:00:02.073652.
# validation [#############################################.....] 90.00%
#          9 iterations
#    0.97053 iters/sec. Estimated time to finish: 0:00:01.030369.
# validation [##################################################] 100.00%
#         10 iterations
#     0.9752 iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [#####.............................................] 10.00%
#          1 iterations
#    0.99056 iters/sec. Estimated time to finish: 0:00:09.085732.
# torch.Size([20, 5]) torch.Size([20])
# validation [##########........................................] 20.00%
#          2 iterations
#    0.94249 iters/sec. Estimated time to finish: 0:00:08.488161.
# torch.Size([20, 5]) torch.Size([20])
# validation [###############...................................] 30.00%
#          3 iterations
#    0.94937 iters/sec. Estimated time to finish: 0:00:07.373316.
# torch.Size([20, 5]) torch.Size([20])
# validation [####################..............................] 40.00%
#          4 iterations
#    0.95673 iters/sec. Estimated time to finish: 0:00:06.271344.
# torch.Size([20, 5]) torch.Size([20])
# validation [#########################.........................] 50.00%
#          5 iterations
#    0.96584 iters/sec. Estimated time to finish: 0:00:05.176822.
# torch.Size([20, 5]) torch.Size([20])
# validation [##############################....................] 60.00%
#          6 iterations
#    0.97444 iters/sec. Estimated time to finish: 0:00:04.104904.
# torch.Size([20, 5]) torch.Size([20])
# validation [###################################...............] 70.00%
#          7 iterations
#    0.96886 iters/sec. Estimated time to finish: 0:00:03.096417.
# torch.Size([20, 5]) torch.Size([20])
# validation [########################################..........] 80.00%
#          8 iterations
#    0.97216 iters/sec. Estimated time to finish: 0:00:02.057265.
# torch.Size([20, 5]) torch.Size([20])
# validation [#############################################.....] 90.00%
#          9 iterations
#    0.97574 iters/sec. Estimated time to finish: 0:00:01.024859.
# 4           160         0.000793893  0.537805    0.812678    0.085       672.396
# validation [#####.............................................] 10.00%
#          1 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [##########........................................] 20.00%
#          2 iterations
#    0.81563 iters/sec. Estimated time to finish: 0:00:09.808325.
# validation [###############...................................] 30.00%
#          3 iterations
#    0.78746 iters/sec. Estimated time to finish: 0:00:08.889374.
# validation [####################..............................] 40.00%
#          4 iterations
#    0.78902 iters/sec. Estimated time to finish: 0:00:07.604325.
# validation [#########################.........................] 50.00%
#          5 iterations
#    0.79087 iters/sec. Estimated time to finish: 0:00:06.322174.
# validation [##############################....................] 60.00%
#          6 iterations
#    0.79537 iters/sec. Estimated time to finish: 0:00:05.029078.
# validation [###################################...............] 70.00%
#          7 iterations
#    0.80099 iters/sec. Estimated time to finish: 0:00:03.745342.
# validation [########################################..........] 80.00%
#          8 iterations
#    0.79627 iters/sec. Estimated time to finish: 0:00:02.511725.
# validation [#############################################.....] 90.00%
#          9 iterations
#    0.80046 iters/sec. Estimated time to finish: 0:00:01.249280.
# validation [##################################################] 100.00%
#         10 iterations
#    0.80428 iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [#####.............................................] 10.00%
#          1 iterations
#    0.81433 iters/sec. Estimated time to finish: 0:00:11.052096.
# torch.Size([20, 5]) torch.Size([20])
# validation [##########........................................] 20.00%
#          2 iterations
#    0.78606 iters/sec. Estimated time to finish: 0:00:10.177291.
# torch.Size([20, 5]) torch.Size([20])
# validation [###############...................................] 30.00%
#          3 iterations
#    0.78936 iters/sec. Estimated time to finish: 0:00:08.867979.
# torch.Size([20, 5]) torch.Size([20])
# validation [####################..............................] 40.00%
#          4 iterations
#     0.7913 iters/sec. Estimated time to finish: 0:00:07.582449.
# torch.Size([20, 5]) torch.Size([20])
# validation [#########################.........................] 50.00%
#          5 iterations
#    0.79814 iters/sec. Estimated time to finish: 0:00:06.264562.
# torch.Size([20, 5]) torch.Size([20])
# validation [##############################....................] 60.00%
#          6 iterations
#    0.80358 iters/sec. Estimated time to finish: 0:00:04.977700.
# torch.Size([20, 5]) torch.Size([20])
# validation [###################################...............] 70.00%
#          7 iterations
#    0.80037 iters/sec. Estimated time to finish: 0:00:03.748249.
# torch.Size([20, 5]) torch.Size([20])
# validation [########################################..........] 80.00%
#          8 iterations
#    0.80298 iters/sec. Estimated time to finish: 0:00:02.490729.
# torch.Size([20, 5]) torch.Size([20])
# validation [#############################################.....] 90.00%
#          9 iterations
#    0.80657 iters/sec. Estimated time to finish: 0:00:01.239814.
# 5           200         0.000654508  0.366761    0.527134    0.085       842.717
# validation [#####.............................................] 10.00%
#          1 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [##########........................................] 20.00%
#          2 iterations
#    0.89561 iters/sec. Estimated time to finish: 0:00:08.932430.
# validation [###############...................................] 30.00%
#          3 iterations
#     0.8572 iters/sec. Estimated time to finish: 0:00:08.166130.
# validation [####################..............................] 40.00%
#          4 iterations
#    0.86864 iters/sec. Estimated time to finish: 0:00:06.907324.
# validation [#########################.........................] 50.00%
#          5 iterations
#    0.87365 iters/sec. Estimated time to finish: 0:00:05.723124.
# validation [##############################....................] 60.00%
#          6 iterations
#    0.87848 iters/sec. Estimated time to finish: 0:00:04.553339.
# validation [###################################...............] 70.00%
#          7 iterations
#    0.88503 iters/sec. Estimated time to finish: 0:00:03.389698.
# validation [########################################..........] 80.00%
#          8 iterations
#    0.88186 iters/sec. Estimated time to finish: 0:00:02.267937.
# validation [#############################################.....] 90.00%
#          9 iterations
#    0.88746 iters/sec. Estimated time to finish: 0:00:01.126813.
# validation [##################################################] 100.00%
#         10 iterations
#    0.89252 iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [#####.............................................] 10.00%
#          1 iterations
#    0.88704 iters/sec. Estimated time to finish: 0:00:10.146097.
# torch.Size([20, 5]) torch.Size([20])
# validation [##########........................................] 20.00%
#          2 iterations
#    0.84884 iters/sec. Estimated time to finish: 0:00:09.424592.
# torch.Size([20, 5]) torch.Size([20])
# validation [###############...................................] 30.00%
#          3 iterations
#    0.85659 iters/sec. Estimated time to finish: 0:00:08.171945.
# torch.Size([20, 5]) torch.Size([20])
# validation [####################..............................] 40.00%
#          4 iterations
#    0.85953 iters/sec. Estimated time to finish: 0:00:06.980567.
# torch.Size([20, 5]) torch.Size([20])
# validation [#########################.........................] 50.00%
#          5 iterations
#    0.87017 iters/sec. Estimated time to finish: 0:00:05.746034.
# torch.Size([20, 5]) torch.Size([20])
# validation [##############################....................] 60.00%
#          6 iterations
#    0.87878 iters/sec. Estimated time to finish: 0:00:04.551775.
# torch.Size([20, 5]) torch.Size([20])
# validation [###################################...............] 70.00%
#          7 iterations
#    0.87546 iters/sec. Estimated time to finish: 0:00:03.426782.
# torch.Size([20, 5]) torch.Size([20])
# validation [########################################..........] 80.00%
#          8 iterations
#    0.87922 iters/sec. Estimated time to finish: 0:00:02.274746.
# torch.Size([20, 5]) torch.Size([20])
# validation [#############################################.....] 90.00%
#          9 iterations
#    0.88516 iters/sec. Estimated time to finish: 0:00:01.129738.
# 6           240         0.0005      0.376632    0.699921    0.09        1012.5
# validation [#####.............................................] 10.00%
#          1 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [##########........................................] 20.00%
#          2 iterations
#    0.80938 iters/sec. Estimated time to finish: 0:00:09.884136.
# validation [###############...................................] 30.00%
#          3 iterations
#    0.77334 iters/sec. Estimated time to finish: 0:00:09.051667.
# validation [####################..............................] 40.00%
#          4 iterations
#    0.78341 iters/sec. Estimated time to finish: 0:00:07.658849.
# validation [#########################.........................] 50.00%
#          5 iterations
#    0.78646 iters/sec. Estimated time to finish: 0:00:06.357605.
# validation [##############################....................] 60.00%
#          6 iterations
#    0.79212 iters/sec. Estimated time to finish: 0:00:05.049771.
# validation [###################################...............] 70.00%
#          7 iterations
#    0.79826 iters/sec. Estimated time to finish: 0:00:03.758195.
# validation [########################################..........] 80.00%
#          8 iterations
#     0.7949 iters/sec. Estimated time to finish: 0:00:02.516049.
# validation [#############################################.....] 90.00%
#          9 iterations
#    0.79839 iters/sec. Estimated time to finish: 0:00:01.252524.
# validation [##################################################] 100.00%
#         10 iterations
#    0.80179 iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [#####.............................................] 10.00%
#          1 iterations
#    0.80499 iters/sec. Estimated time to finish: 0:00:11.180254.
# torch.Size([20, 5]) torch.Size([20])
# validation [##########........................................] 20.00%
#          2 iterations
#    0.77064 iters/sec. Estimated time to finish: 0:00:10.380983.
# torch.Size([20, 5]) torch.Size([20])
# validation [###############...................................] 30.00%
#          3 iterations
#    0.78137 iters/sec. Estimated time to finish: 0:00:08.958582.
# torch.Size([20, 5]) torch.Size([20])
# validation [####################..............................] 40.00%
#          4 iterations
#    0.78691 iters/sec. Estimated time to finish: 0:00:07.624745.
# torch.Size([20, 5]) torch.Size([20])
# validation [#########################.........................] 50.00%
#          5 iterations
#    0.79375 iters/sec. Estimated time to finish: 0:00:06.299191.
# torch.Size([20, 5]) torch.Size([20])
# validation [##############################....................] 60.00%
#          6 iterations
#    0.79755 iters/sec. Estimated time to finish: 0:00:05.015345.
# torch.Size([20, 5]) torch.Size([20])
# validation [###################################...............] 70.00%
#          7 iterations
#    0.79248 iters/sec. Estimated time to finish: 0:00:03.785573.
# torch.Size([20, 5]) torch.Size([20])
# validation [########################################..........] 80.00%
#          8 iterations
#    0.79618 iters/sec. Estimated time to finish: 0:00:02.512010.
# torch.Size([20, 5]) torch.Size([20])
# validation [#############################################.....] 90.00%
#          9 iterations
#     0.7989 iters/sec. Estimated time to finish: 0:00:01.251728.
# 7           280         0.000345492  0.302281    0.469768    0.09        1186.09
# validation [#####.............................................] 10.00%
#          1 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [##########........................................] 20.00%
#          2 iterations
#    0.80684 iters/sec. Estimated time to finish: 0:00:09.915169.
# validation [###############...................................] 30.00%
#          3 iterations
#    0.76711 iters/sec. Estimated time to finish: 0:00:09.125164.
# validation [####################..............................] 40.00%
#          4 iterations
#     0.7794 iters/sec. Estimated time to finish: 0:00:07.698227.
# validation [#########################.........................] 50.00%
#          5 iterations
#    0.78413 iters/sec. Estimated time to finish: 0:00:06.376497.
# validation [##############################....................] 60.00%
#          6 iterations
#    0.79014 iters/sec. Estimated time to finish: 0:00:05.062363.
# validation [###################################...............] 70.00%
#          7 iterations
#     0.7971 iters/sec. Estimated time to finish: 0:00:03.763664.
# validation [########################################..........] 80.00%
#          8 iterations
#     0.7935 iters/sec. Estimated time to finish: 0:00:02.520481.
# validation [#############################################.....] 90.00%
#          9 iterations
#    0.79779 iters/sec. Estimated time to finish: 0:00:01.253457.
# validation [##################################################] 100.00%
#         10 iterations
#    0.80124 iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [#####.............................................] 10.00%
#          1 iterations
#    0.80768 iters/sec. Estimated time to finish: 0:00:11.143072.
# torch.Size([20, 5]) torch.Size([20])
# validation [##########........................................] 20.00%
#          2 iterations
#    0.76696 iters/sec. Estimated time to finish: 0:00:10.430765.
# torch.Size([20, 5]) torch.Size([20])
# validation [###############...................................] 30.00%
#          3 iterations
#    0.77679 iters/sec. Estimated time to finish: 0:00:09.011421.
# torch.Size([20, 5]) torch.Size([20])
# validation [####################..............................] 40.00%
#          4 iterations
#    0.78331 iters/sec. Estimated time to finish: 0:00:07.659755.
# torch.Size([20, 5]) torch.Size([20])
# validation [#########################.........................] 50.00%
#          5 iterations
#    0.78981 iters/sec. Estimated time to finish: 0:00:06.330622.
# torch.Size([20, 5]) torch.Size([20])
# validation [##############################....................] 60.00%
#          6 iterations
#    0.79476 iters/sec. Estimated time to finish: 0:00:05.032962.
# torch.Size([20, 5]) torch.Size([20])
# validation [###################################...............] 70.00%
#          7 iterations
#    0.79271 iters/sec. Estimated time to finish: 0:00:03.784503.
# torch.Size([20, 5]) torch.Size([20])
# validation [########################################..........] 80.00%
#          8 iterations
#    0.79739 iters/sec. Estimated time to finish: 0:00:02.508191.
# torch.Size([20, 5]) torch.Size([20])
# validation [#############################################.....] 90.00%
#          9 iterations
#    0.80174 iters/sec. Estimated time to finish: 0:00:01.247287.
# 8           320         0.000206107  0.27355     0.490519    0.09        1359.72
# validation [#####.............................................] 10.00%
#          1 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [##########........................................] 20.00%
#          2 iterations
#    0.80469 iters/sec. Estimated time to finish: 0:00:09.941727.
# validation [###############...................................] 30.00%
#          3 iterations
#    0.76055 iters/sec. Estimated time to finish: 0:00:09.203910.
# validation [####################..............................] 40.00%
#          4 iterations
#    0.77155 iters/sec. Estimated time to finish: 0:00:07.776592.
# validation [#########################.........................] 50.00%
#          5 iterations
#    0.77918 iters/sec. Estimated time to finish: 0:00:06.416997.
# validation [##############################....................] 60.00%
#          6 iterations
#    0.78522 iters/sec. Estimated time to finish: 0:00:05.094132.
# validation [###################################...............] 70.00%
#          7 iterations
#    0.79115 iters/sec. Estimated time to finish: 0:00:03.791964.
# validation [########################################..........] 80.00%
#          8 iterations
#    0.78932 iters/sec. Estimated time to finish: 0:00:02.533820.
# validation [#############################################.....] 90.00%
#          9 iterations
#    0.79424 iters/sec. Estimated time to finish: 0:00:01.259071.
# validation [##################################################] 100.00%
#         10 iterations
#    0.79798 iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [#####.............................................] 10.00%
#          1 iterations
#    0.81139 iters/sec. Estimated time to finish: 0:00:11.092102.
# torch.Size([20, 5]) torch.Size([20])
# validation [##########........................................] 20.00%
#          2 iterations
#    0.76988 iters/sec. Estimated time to finish: 0:00:10.391191.
# torch.Size([20, 5]) torch.Size([20])
# validation [###############...................................] 30.00%
#          3 iterations
#    0.77907 iters/sec. Estimated time to finish: 0:00:08.985028.
# torch.Size([20, 5]) torch.Size([20])
# validation [####################..............................] 40.00%
#          4 iterations
#    0.78476 iters/sec. Estimated time to finish: 0:00:07.645650.
# torch.Size([20, 5]) torch.Size([20])
# validation [#########################.........................] 50.00%
#          5 iterations
#    0.79287 iters/sec. Estimated time to finish: 0:00:06.306190.
# torch.Size([20, 5]) torch.Size([20])
# validation [##############################....................] 60.00%
#          6 iterations
#     0.7984 iters/sec. Estimated time to finish: 0:00:05.010009.
# torch.Size([20, 5]) torch.Size([20])
# validation [###################################...............] 70.00%
#          7 iterations
#    0.79543 iters/sec. Estimated time to finish: 0:00:03.771528.
# torch.Size([20, 5]) torch.Size([20])
# validation [########################################..........] 80.00%
#          8 iterations
#     0.7987 iters/sec. Estimated time to finish: 0:00:02.504071.
# torch.Size([20, 5]) torch.Size([20])
# validation [#############################################.....] 90.00%
#          9 iterations
#     0.8026 iters/sec. Estimated time to finish: 0:00:01.245944.
# 9           360         9.54915e-05  0.282607    0.451368    0.09        1533.49
# validation [#####.............................................] 10.00%
#          1 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [##########........................................] 20.00%
#          2 iterations
#     0.8094 iters/sec. Estimated time to finish: 0:00:09.883848.
# validation [###############...................................] 30.00%
#          3 iterations
#     0.7741 iters/sec. Estimated time to finish: 0:00:09.042704.
# validation [####################..............................] 40.00%
#          4 iterations
#    0.78371 iters/sec. Estimated time to finish: 0:00:07.655934.
# validation [#########################.........................] 50.00%
#          5 iterations
#    0.78871 iters/sec. Estimated time to finish: 0:00:06.339499.
# validation [##############################....................] 60.00%
#          6 iterations
#    0.79411 iters/sec. Estimated time to finish: 0:00:05.037113.
# validation [###################################...............] 70.00%
#          7 iterations
#    0.80001 iters/sec. Estimated time to finish: 0:00:03.749963.
# validation [########################################..........] 80.00%
#          8 iterations
#    0.79515 iters/sec. Estimated time to finish: 0:00:02.515255.
# validation [#############################################.....] 90.00%
#          9 iterations
#    0.79943 iters/sec. Estimated time to finish: 0:00:01.250894.
# validation [##################################################] 100.00%
#         10 iterations
#    0.80242 iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [#####.............................................] 10.00%
#          1 iterations
#     0.8104 iters/sec. Estimated time to finish: 0:00:11.105652.
# torch.Size([20, 5]) torch.Size([20])
# validation [##########........................................] 20.00%
#          2 iterations
#    0.77978 iters/sec. Estimated time to finish: 0:00:10.259247.
# torch.Size([20, 5]) torch.Size([20])
# validation [###############...................................] 30.00%
#          3 iterations
#    0.78501 iters/sec. Estimated time to finish: 0:00:08.917057.
# torch.Size([20, 5]) torch.Size([20])
# validation [####################..............................] 40.00%
#          4 iterations
#    0.78823 iters/sec. Estimated time to finish: 0:00:07.612016.
# torch.Size([20, 5]) torch.Size([20])
# validation [#########################.........................] 50.00%
#          5 iterations
#    0.79472 iters/sec. Estimated time to finish: 0:00:06.291555.
# torch.Size([20, 5]) torch.Size([20])
# validation [##############################....................] 60.00%
#          6 iterations
#    0.80064 iters/sec. Estimated time to finish: 0:00:04.996006.
# torch.Size([20, 5]) torch.Size([20])
# validation [###################################...............] 70.00%
#          7 iterations
#    0.79445 iters/sec. Estimated time to finish: 0:00:03.776216.
# torch.Size([20, 5]) torch.Size([20])
# validation [########################################..........] 80.00%
#          8 iterations
#    0.79879 iters/sec. Estimated time to finish: 0:00:02.503787.
# torch.Size([20, 5]) torch.Size([20])
# validation [#############################################.....] 90.00%
#          9 iterations
#    0.80267 iters/sec. Estimated time to finish: 0:00:01.245847.
# 10          400         2.44717e-05  0.272347    0.409775    0.085       1708.13
# validation [#####.............................................] 10.00%
#          1 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [##########........................................] 20.00%
#          2 iterations
#     0.8016 iters/sec. Estimated time to finish: 0:00:09.980083.
# validation [###############...................................] 30.00%
#          3 iterations
#    0.77026 iters/sec. Estimated time to finish: 0:00:09.087796.
# validation [####################..............................] 40.00%
#          4 iterations
#    0.77612 iters/sec. Estimated time to finish: 0:00:07.730730.
# validation [#########################.........................] 50.00%
#          5 iterations
#    0.78143 iters/sec. Estimated time to finish: 0:00:06.398544.
# validation [##############################....................] 60.00%
#          6 iterations
#     0.7888 iters/sec. Estimated time to finish: 0:00:05.070978.
# validation [###################################...............] 70.00%
#          7 iterations
#    0.79413 iters/sec. Estimated time to finish: 0:00:03.777736.
# validation [########################################..........] 80.00%
#          8 iterations
#    0.79164 iters/sec. Estimated time to finish: 0:00:02.526415.
# validation [#############################################.....] 90.00%
#          9 iterations
#    0.79611 iters/sec. Estimated time to finish: 0:00:01.256115.
# validation [##################################################] 100.00%
#         10 iterations
#    0.79994 iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [#####.............................................] 10.00%
#          1 iterations
#    0.80951 iters/sec. Estimated time to finish: 0:00:11.117870.
# torch.Size([20, 5]) torch.Size([20])
# validation [##########........................................] 20.00%
#          2 iterations
#    0.77525 iters/sec. Estimated time to finish: 0:00:10.319314.
# torch.Size([20, 5]) torch.Size([20])
# validation [###############...................................] 30.00%
#          3 iterations
#    0.77978 iters/sec. Estimated time to finish: 0:00:08.976941.
# torch.Size([20, 5]) torch.Size([20])
# validation [####################..............................] 40.00%
#          4 iterations
#    0.78328 iters/sec. Estimated time to finish: 0:00:07.660060.
# torch.Size([20, 5]) torch.Size([20])
# validation [#########################.........................] 50.00%
#          5 iterations
#     0.7906 iters/sec. Estimated time to finish: 0:00:06.324287.
# torch.Size([20, 5]) torch.Size([20])
# validation [##############################....................] 60.00%
#          6 iterations
#    0.79693 iters/sec. Estimated time to finish: 0:00:05.019237.
# torch.Size([20, 5]) torch.Size([20])
# validation [###################################...............] 70.00%
#          7 iterations
#    0.79143 iters/sec. Estimated time to finish: 0:00:03.790630.
# torch.Size([20, 5]) torch.Size([20])
# validation [########################################..........] 80.00%
#          8 iterations
#     0.7947 iters/sec. Estimated time to finish: 0:00:02.516684.
# torch.Size([20, 5]) torch.Size([20])
# validation [#############################################.....] 90.00%
#          9 iterations
#    0.79868 iters/sec. Estimated time to finish: 0:00:01.252065.
# 11          440         0           0.291603    0.33686     0.08        1882.92
# validation [#####.............................................] 10.00%
#          1 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [##########........................................] 20.00%
#          2 iterations
#    0.80933 iters/sec. Estimated time to finish: 0:00:09.884764.
# validation [###############...................................] 30.00%
#          3 iterations
#    0.77161 iters/sec. Estimated time to finish: 0:00:09.071957.
# validation [####################..............................] 40.00%
#          4 iterations
#    0.78055 iters/sec. Estimated time to finish: 0:00:07.686850.
# validation [#########################.........................] 50.00%
#          5 iterations
#    0.78487 iters/sec. Estimated time to finish: 0:00:06.370474.
# validation [##############################....................] 60.00%
#          6 iterations
#    0.79051 iters/sec. Estimated time to finish: 0:00:05.060013.
# validation [###################################...............] 70.00%
#          7 iterations
#    0.79595 iters/sec. Estimated time to finish: 0:00:03.769090.
# validation [########################################..........] 80.00%
#          8 iterations
#    0.79101 iters/sec. Estimated time to finish: 0:00:02.528410.
# validation [#############################################.....] 90.00%
#          9 iterations
#    0.79531 iters/sec. Estimated time to finish: 0:00:01.257367.
# validation [##################################################] 100.00%
#         10 iterations
#    0.79924 iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [#####.............................................] 10.00%
#          1 iterations
#    0.81226 iters/sec. Estimated time to finish: 0:00:11.080160.
# torch.Size([20, 5]) torch.Size([20])
# validation [##########........................................] 20.00%
#          2 iterations
#    0.77123 iters/sec. Estimated time to finish: 0:00:10.373053.
# torch.Size([20, 5]) torch.Size([20])
# validation [###############...................................] 30.00%
#          3 iterations
#    0.78127 iters/sec. Estimated time to finish: 0:00:08.959721.
# torch.Size([20, 5]) torch.Size([20])
# validation [####################..............................] 40.00%
#          4 iterations
#    0.78297 iters/sec. Estimated time to finish: 0:00:07.663129.
# torch.Size([20, 5]) torch.Size([20])
# validation [#########################.........................] 50.00%
#          5 iterations
#     0.7905 iters/sec. Estimated time to finish: 0:00:06.325097.
# torch.Size([20, 5]) torch.Size([20])
# validation [##############################....................] 60.00%
#          6 iterations
#    0.79528 iters/sec. Estimated time to finish: 0:00:05.029668.
# torch.Size([20, 5]) torch.Size([20])
# validation [###################################...............] 70.00%
#          7 iterations
#    0.79043 iters/sec. Estimated time to finish: 0:00:03.795418.
# torch.Size([20, 5]) torch.Size([20])
# validation [########################################..........] 80.00%
#          8 iterations
#     0.7918 iters/sec. Estimated time to finish: 0:00:02.525876.
# torch.Size([20, 5]) torch.Size([20])
# validation [#############################################.....] 90.00%
#          9 iterations
#    0.79607 iters/sec. Estimated time to finish: 0:00:01.256171.
# 12          480         2.44717e-05  0.219307    0.392623    0.08        2058.01
# validation [#####.............................................] 10.00%
#          1 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [##########........................................] 20.00%
#          2 iterations
#     0.8751 iters/sec. Estimated time to finish: 0:00:09.141844.
# validation [###############...................................] 30.00%
#          3 iterations
#    0.84402 iters/sec. Estimated time to finish: 0:00:08.293683.
# validation [####################..............................] 40.00%
#          4 iterations
#    0.84694 iters/sec. Estimated time to finish: 0:00:07.084306.
# validation [#########################.........................] 50.00%
#          5 iterations
#    0.85423 iters/sec. Estimated time to finish: 0:00:05.853230.
# validation [##############################....................] 60.00%
#          6 iterations
#    0.86249 iters/sec. Estimated time to finish: 0:00:04.637746.
# validation [###################################...............] 70.00%
#          7 iterations
#    0.86991 iters/sec. Estimated time to finish: 0:00:03.448619.
# validation [########################################..........] 80.00%
#          8 iterations
#    0.86389 iters/sec. Estimated time to finish: 0:00:02.315110.
# validation [#############################################.....] 90.00%
#          9 iterations
#    0.86919 iters/sec. Estimated time to finish: 0:00:01.150490.
# validation [##################################################] 100.00%
#         10 iterations
#    0.87298 iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [#####.............................................] 10.00%
#          1 iterations
#    0.87003 iters/sec. Estimated time to finish: 0:00:10.344415.
# torch.Size([20, 5]) torch.Size([20])
# validation [##########........................................] 20.00%
#          2 iterations
#    0.84314 iters/sec. Estimated time to finish: 0:00:09.488328.
# torch.Size([20, 5]) torch.Size([20])
# validation [###############...................................] 30.00%
#          3 iterations
#    0.85483 iters/sec. Estimated time to finish: 0:00:08.188729.
# torch.Size([20, 5]) torch.Size([20])
# validation [####################..............................] 40.00%
#          4 iterations
#    0.86087 iters/sec. Estimated time to finish: 0:00:06.969688.
# torch.Size([20, 5]) torch.Size([20])
# validation [#########################.........................] 50.00%
#          5 iterations
#    0.86731 iters/sec. Estimated time to finish: 0:00:05.764927.
# torch.Size([20, 5]) torch.Size([20])
# validation [##############################....................] 60.00%
#          6 iterations
#    0.87405 iters/sec. Estimated time to finish: 0:00:04.576390.
# torch.Size([20, 5]) torch.Size([20])
# validation [###################################...............] 70.00%
#          7 iterations
#    0.86856 iters/sec. Estimated time to finish: 0:00:03.453998.
# torch.Size([20, 5]) torch.Size([20])
# validation [########################################..........] 80.00%
#          8 iterations
#     0.8736 iters/sec. Estimated time to finish: 0:00:02.289381.
# torch.Size([20, 5]) torch.Size([20])
# validation [#############################################.....] 90.00%
#          9 iterations
#    0.87783 iters/sec. Estimated time to finish: 0:00:01.139175.
# 13          520         9.54915e-05  0.227267    0.398194    0.09        2231.09
# validation [#####.............................................] 10.00%
#          1 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [##########........................................] 20.00%
#          2 iterations
#    0.82847 iters/sec. Estimated time to finish: 0:00:09.656347.
# validation [###############...................................] 30.00%
#          3 iterations
#    0.72889 iters/sec. Estimated time to finish: 0:00:09.603704.
# validation [####################..............................] 40.00%
#          4 iterations
#    0.72592 iters/sec. Estimated time to finish: 0:00:08.265374.
# validation [#########################.........................] 50.00%
#          5 iterations
#     0.7383 iters/sec. Estimated time to finish: 0:00:06.772277.
# validation [##############################....................] 60.00%
#          6 iterations
#      0.743 iters/sec. Estimated time to finish: 0:00:05.383566.
# validation [###################################...............] 70.00%
#          7 iterations
#    0.76501 iters/sec. Estimated time to finish: 0:00:03.921524.
# ...
# torch.Size([20, 5]) torch.Size([20])
# validation [##########........................................] 20.00%
#          2 iterations
#    0.77079 iters/sec. Estimated time to finish: 0:00:10.378973.
# torch.Size([20, 5]) torch.Size([20])
# validation [###############...................................] 30.00%
#          3 iterations
#    0.78215 iters/sec. Estimated time to finish: 0:00:08.949659.
# torch.Size([20, 5]) torch.Size([20])
# validation [####################..............................] 40.00%
#          4 iterations
#    0.78742 iters/sec. Estimated time to finish: 0:00:07.619830.
# torch.Size([20, 5]) torch.Size([20])
# validation [#########################.........................] 50.00%
#          5 iterations
#    0.79362 iters/sec. Estimated time to finish: 0:00:06.300244.
# torch.Size([20, 5]) torch.Size([20])
# validation [##############################....................] 60.00%
#          6 iterations
#     0.7992 iters/sec. Estimated time to finish: 0:00:05.004994.
# torch.Size([20, 5]) torch.Size([20])
# validation [###################################...............] 70.00%
#          7 iterations
#     0.7958 iters/sec. Estimated time to finish: 0:00:03.769799.
# torch.Size([20, 5]) torch.Size([20])
# validation [########################################..........] 80.00%
#          8 iterations
#    0.79993 iters/sec. Estimated time to finish: 0:00:02.500225.
# torch.Size([20, 5]) torch.Size([20])
# validation [#############################################.....] 90.00%
#          9 iterations
#    0.80224 iters/sec. Estimated time to finish: 0:00:01.246512.
# 16          640         0.0005      0.270234    0.311233    0.09        2755.7
# validation [#####.............................................] 10.00%
#          1 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [##########........................................] 20.00%
#          2 iterations
#    0.81486 iters/sec. Estimated time to finish: 0:00:09.817614.
# validation [###############...................................] 30.00%
#          3 iterations
#    0.78105 iters/sec. Estimated time to finish: 0:00:08.962288.
# validation [####################..............................] 40.00%
#          4 iterations
#    0.78846 iters/sec. Estimated time to finish: 0:00:07.609796.
# validation [#########################.........................] 50.00%
#          5 iterations
#    0.78935 iters/sec. Estimated time to finish: 0:00:06.334324.
# validation [##############################....................] 60.00%
#          6 iterations
#    0.79599 iters/sec. Estimated time to finish: 0:00:05.025219.
# validation [###################################...............] 70.00%
#          7 iterations
#    0.80199 iters/sec. Estimated time to finish: 0:00:03.740677.
# validation [########################################..........] 80.00%
#          8 iterations
#    0.79771 iters/sec. Estimated time to finish: 0:00:02.507175.
# validation [#############################################.....] 90.00%
#          9 iterations
#    0.80214 iters/sec. Estimated time to finish: 0:00:01.246671.
# validation [##################################################] 100.00%
#         10 iterations
#     0.8062 iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [#####.............................................] 10.00%
#          1 iterations
#    0.79969 iters/sec. Estimated time to finish: 0:00:11.254317.
# torch.Size([20, 5]) torch.Size([20])
# validation [##########........................................] 20.00%
#          2 iterations
#    0.77677 iters/sec. Estimated time to finish: 0:00:10.299009.
# torch.Size([20, 5]) torch.Size([20])
# validation [###############...................................] 30.00%
#          3 iterations
#    0.78238 iters/sec. Estimated time to finish: 0:00:08.947067.
# torch.Size([20, 5]) torch.Size([20])
# validation [####################..............................] 40.00%
#          4 iterations
#    0.78685 iters/sec. Estimated time to finish: 0:00:07.625369.
# torch.Size([20, 5]) torch.Size([20])
# validation [#########################.........................] 50.00%
#          5 iterations
#    0.79238 iters/sec. Estimated time to finish: 0:00:06.310117.
# torch.Size([20, 5]) torch.Size([20])
# validation [##############################....................] 60.00%
#          6 iterations
#     0.7974 iters/sec. Estimated time to finish: 0:00:05.016279.
# torch.Size([20, 5]) torch.Size([20])
# validation [###################################...............] 70.00%
#          7 iterations
#    0.79486 iters/sec. Estimated time to finish: 0:00:03.774245.
# torch.Size([20, 5]) torch.Size([20])
# validation [########################################..........] 80.00%
#          8 iterations
#    0.79852 iters/sec. Estimated time to finish: 0:00:02.504623.
# torch.Size([20, 5]) torch.Size([20])
# validation [#############################################.....] 90.00%
#          9 iterations
#      0.801 iters/sec. Estimated time to finish: 0:00:01.248442.
# 17          680         0.000654508  0.269275    0.629273    0.085       2931.47
# validation [#####.............................................] 10.00%
#          1 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [##########........................................] 20.00%
#          2 iterations
#    0.89647 iters/sec. Estimated time to finish: 0:00:08.923891.
# validation [###############...................................] 30.00%
#          3 iterations
#    0.86419 iters/sec. Estimated time to finish: 0:00:08.100068.
# validation [####################..............................] 40.00%
#          4 iterations
#    0.86653 iters/sec. Estimated time to finish: 0:00:06.924143.
# validation [#########################.........................] 50.00%
#          5 iterations
#     0.8731 iters/sec. Estimated time to finish: 0:00:05.726695.
# validation [##############################....................] 60.00%
#          6 iterations
#    0.88184 iters/sec. Estimated time to finish: 0:00:04.535981.
# validation [###################################...............] 70.00%
#          7 iterations
#    0.88772 iters/sec. Estimated time to finish: 0:00:03.379461.
# validation [########################################..........] 80.00%
#          8 iterations
#    0.88398 iters/sec. Estimated time to finish: 0:00:02.262503.
# validation [#############################################.....] 90.00%
#          9 iterations
#    0.88707 iters/sec. Estimated time to finish: 0:00:01.127306.
# validation [##################################################] 100.00%
#         10 iterations
#    0.89186 iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [#####.............................................] 10.00%
#          1 iterations
#    0.87969 iters/sec. Estimated time to finish: 0:00:10.230922.
# torch.Size([20, 5]) torch.Size([20])
# validation [##########........................................] 20.00%
#          2 iterations
#    0.85767 iters/sec. Estimated time to finish: 0:00:09.327574.
# torch.Size([20, 5]) torch.Size([20])
# validation [###############...................................] 30.00%
#          3 iterations
#     0.8699 iters/sec. Estimated time to finish: 0:00:08.046885.
# torch.Size([20, 5]) torch.Size([20])
# validation [####################..............................] 40.00%
#          4 iterations
#    0.87538 iters/sec. Estimated time to finish: 0:00:06.854156.
# torch.Size([20, 5]) torch.Size([20])
# validation [#########################.........................] 50.00%
#          5 iterations
#    0.88413 iters/sec. Estimated time to finish: 0:00:05.655279.
# torch.Size([20, 5]) torch.Size([20])
# validation [##############################....................] 60.00%
#          6 iterations
#    0.88812 iters/sec. Estimated time to finish: 0:00:04.503909.
# torch.Size([20, 5]) torch.Size([20])
# validation [###################################...............] 70.00%
#          7 iterations
#    0.88457 iters/sec. Estimated time to finish: 0:00:03.391496.
# torch.Size([20, 5]) torch.Size([20])
# validation [########################################..........] 80.00%
#          8 iterations
#    0.89005 iters/sec. Estimated time to finish: 0:00:02.247067.
# torch.Size([20, 5]) torch.Size([20])
# validation [#############################################.....] 90.00%
#          9 iterations
#    0.89393 iters/sec. Estimated time to finish: 0:00:01.118660.
# 18          720         0.000793893  0.459311    0.789766    0.08        3104.81
# validation [#####.............................................] 10.00%
#          1 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [##########........................................] 20.00%
#          2 iterations
#    0.89219 iters/sec. Estimated time to finish: 0:00:08.966740.
# validation [###############...................................] 30.00%
#          3 iterations
#    0.85484 iters/sec. Estimated time to finish: 0:00:08.188661.
# validation [####################..............................] 40.00%
#          4 iterations
#    0.86665 iters/sec. Estimated time to finish: 0:00:06.923234.
# validation [#########################.........................] 50.00%
#          5 iterations
#    0.87253 iters/sec. Estimated time to finish: 0:00:05.730452.
# validation [##############################....................] 60.00%
#          6 iterations
#    0.88003 iters/sec. Estimated time to finish: 0:00:04.545307.
# validation [###################################...............] 70.00%
#          7 iterations
#    0.88596 iters/sec. Estimated time to finish: 0:00:03.386155.
# validation [########################################..........] 80.00%
#          8 iterations
#    0.88086 iters/sec. Estimated time to finish: 0:00:02.270502.
# validation [#############################################.....] 90.00%
#          9 iterations
#    0.88677 iters/sec. Estimated time to finish: 0:00:01.127694.
# validation [##################################################] 100.00%
#         10 iterations
#     0.8915 iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [#####.............................................] 10.00%
#          1 iterations
#    0.89226 iters/sec. Estimated time to finish: 0:00:10.086765.
# torch.Size([20, 5]) torch.Size([20])
# validation [##########........................................] 20.00%
#          2 iterations
#    0.86219 iters/sec. Estimated time to finish: 0:00:09.278706.
# torch.Size([20, 5]) torch.Size([20])
# validation [###############...................................] 30.00%
#          3 iterations
#    0.86917 iters/sec. Estimated time to finish: 0:00:08.053637.
# torch.Size([20, 5]) torch.Size([20])
# validation [####################..............................] 40.00%
#          4 iterations
#    0.87529 iters/sec. Estimated time to finish: 0:00:06.854902.
# torch.Size([20, 5]) torch.Size([20])
# validation [#########################.........................] 50.00%
#          5 iterations
#    0.88293 iters/sec. Estimated time to finish: 0:00:05.662957.
# torch.Size([20, 5]) torch.Size([20])
# validation [##############################....................] 60.00%
#          6 iterations
#    0.88694 iters/sec. Estimated time to finish: 0:00:04.509904.
# torch.Size([20, 5]) torch.Size([20])
# validation [###################################...............] 70.00%
#          7 iterations
#    0.88379 iters/sec. Estimated time to finish: 0:00:03.394480.
# torch.Size([20, 5]) torch.Size([20])
# validation [########################################..........] 80.00%
#          8 iterations
#    0.88906 iters/sec. Estimated time to finish: 0:00:02.249570.
# torch.Size([20, 5]) torch.Size([20])
# validation [#############################################.....] 90.00%
#          9 iterations
#    0.89333 iters/sec. Estimated time to finish: 0:00:01.119413.
# 19          760         0.000904508  0.442272    0.732689    0.09        3275.61
# validation [#####.............................................] 10.00%
#          1 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [##########........................................] 20.00%
#          2 iterations
#    0.87923 iters/sec. Estimated time to finish: 0:00:09.098839.
# validation [###############...................................] 30.00%
#          3 iterations
#    0.85052 iters/sec. Estimated time to finish: 0:00:08.230241.
# validation [####################..............................] 40.00%
#          4 iterations
#    0.86404 iters/sec. Estimated time to finish: 0:00:06.944114.
# validation [#########################.........................] 50.00%
#          5 iterations
#    0.87076 iters/sec. Estimated time to finish: 0:00:05.742100.
# validation [##############################....................] 60.00%
#          6 iterations
#    0.87944 iters/sec. Estimated time to finish: 0:00:04.548344.
# validation [###################################...............] 70.00%
#          7 iterations
#    0.88559 iters/sec. Estimated time to finish: 0:00:03.387566.
# validation [########################################..........] 80.00%
#          8 iterations
#    0.88094 iters/sec. Estimated time to finish: 0:00:02.270302.
# validation [#############################################.....] 90.00%
#          9 iterations
#     0.8865 iters/sec. Estimated time to finish: 0:00:01.128037.
# validation [##################################################] 100.00%
#         10 iterations
#    0.88918 iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [#####.............................................] 10.00%
#          1 iterations
#    0.90094 iters/sec. Estimated time to finish: 0:00:09.989585.
# torch.Size([20, 5]) torch.Size([20])
# validation [##########........................................] 20.00%
#          2 iterations
#    0.86192 iters/sec. Estimated time to finish: 0:00:09.281605.
# torch.Size([20, 5]) torch.Size([20])
# validation [###############...................................] 30.00%
#          3 iterations
#    0.86862 iters/sec. Estimated time to finish: 0:00:08.058736.
# torch.Size([20, 5]) torch.Size([20])
# validation [####################..............................] 40.00%
#          4 iterations
#    0.87412 iters/sec. Estimated time to finish: 0:00:06.864062.
# torch.Size([20, 5]) torch.Size([20])
# validation [#########################.........................] 50.00%
#          5 iterations
#    0.87749 iters/sec. Estimated time to finish: 0:00:05.698070.
# torch.Size([20, 5]) torch.Size([20])
# validation [##############################....................] 60.00%
#          6 iterations
#     0.8855 iters/sec. Estimated time to finish: 0:00:04.517246.
# torch.Size([20, 5]) torch.Size([20])
# validation [###################################...............] 70.00%
#          7 iterations
#     0.8821 iters/sec. Estimated time to finish: 0:00:03.400958.
# torch.Size([20, 5]) torch.Size([20])
# validation [########################################..........] 80.00%
#          8 iterations
#    0.88509 iters/sec. Estimated time to finish: 0:00:02.259667.
# torch.Size([20, 5]) torch.Size([20])
# validation [#############################################.....] 90.00%
#          9 iterations
#    0.88913 iters/sec. Estimated time to finish: 0:00:01.124697.
# 20          800         0.000975528  0.414338    1.00014     0.075       3446.83
