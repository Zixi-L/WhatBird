# %%
import os
import gc
import time
import shutil
import random
import warnings
import typing as tp
from pathlib import Path
from contextlib import contextmanager

import yaml
from joblib import delayed, Parallel

import cv2
import librosa
import audioread
import soundfile as sf

import numpy as np
import pandas as pd

from sklearn.metrics import f1_score
from sklearn.model_selection import StratifiedKFold

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.utils.data as data
import resnest.torch as resnest_torch

import pytorch_pfn_extras as ppe
from pytorch_pfn_extras.training import extensions as ppe_extensions
import pytorch_pfn_extras.training.extensions as extensions
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score


from ignite.engine import Events
from ignite.engine import create_supervised_trainer
from ignite.engine import create_supervised_evaluator
from ignite.metrics import Accuracy, Loss

pd.options.display.max_rows = 500
pd.options.display.max_columns = 500

# %% [markdown]
# ### define utilities

# %%
def set_seed(seed: int = 42):
    random.seed(seed)
    np.random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)  # type: ignore
#     torch.backends.cudnn.deterministic = True  # type: ignore
#     torch.backends.cudnn.benchmark = True  # type: ignore
    

@contextmanager
def timer(name: str) -> None:
    """Timer Util"""
    t0 = time.time()
    print("[{}] start".format(name))
    yield
    print("[{}] done in {:.0f} s".format(name, time.time() - t0))

# %% [markdown]
# ### read data

# %%
TRAIN_AUDIO_DIR = Path( "data")
TRAIN_RESAMPLED_AUDIO_DIRS = Path( "data")
TRAIN_RESAMPLED_AUDIO_DIRS.iterdir()
# Out:
# <generator object Path.iterdir at 0x7fde92876b50>

# %%
train=pd.read_csv('train_5.csv')

# %%
# bird_list = ['bkcchi','blujay','bulori','chispa','wilfly']
# train = df[df['ebird_code'].isin(['bkcchi','blujay','bulori','chispa','wilfly'])]
# train.to_csv('train_5.csv')

# %%
train.head(2)
# Out:
#    Unnamed: 0  rating playback_used ebird_code  channels        date  \
# 0        2064     4.0            no     bkcchi  1 (mono)  2010-10-15
# 1        2065     4.5            no     bkcchi  1 (mono)  2012-12-03
#
#            pitch  duration      filename          speed  \
# 0           both        18  XC114073.mp3           both
# 1  Not specified        83  XC114086.mp3  Not specified
#
#                   species number_of_notes  \
# 0  Black-capped Chickadee             4-6
# 1  Black-capped Chickadee   Not specified
#
#                                                title  \
# 0  XC114073 Black-capped Chickadee (Poecile atric...
# 1  XC114086 Black-capped Chickadee (Poecile atric...
#
#                           secondary_labels bird_seen              sci_name  \
# 0                                       []       yes  Poecile atricapillus
# 1  ['Corvus brachyrhynchos_American Crow']       yes  Poecile atricapillus
#
#                                             location latitude sampling_rate  \
# 0   Environmental Learning Center, Fort Collins, ...   40.557    48000 (Hz)
# 1   Powderhorn Park, Minneapolis, Hennepin, Minne...   44.942    44100 (Hz)
#
#    type elevation                                        description  \
# 0  call    1500 m  Three individuals foraging in the open woods n...
# 1  call     260 m  Calls from a single bird foraging in conifer t...
#
#   bitrate_of_mp3 file_type         volume  \
# 0    48000 (bps)       mp3     increasing
# 1   128000 (bps)       mp3  Not specified
#
#                               background   xc_id  \
# 0                                    NaN  114073
# 1  American Crow (Corvus brachyrhynchos)  114086
#
#                                  url        country            author  \
# 0  https://www.xeno-canto.org/114073  United States      Eric DeFonso
# 1  https://www.xeno-canto.org/114086  United States  Jonathon Jongsma
#
#                                  primary_label longitude         length  \
# 0  Poecile atricapillus_Black-capped Chickadee  -105.017         0-3(s)
# 1  Poecile atricapillus_Black-capped Chickadee   -93.259  Not specified
#
#     time         recordist                                            license
# 0  11:46      Eric DeFonso  Creative Commons Attribution-NonCommercial-Sha...
# 1  14:26  Jonathon Jongsma        Creative Commons Attribution-ShareAlike 3.0

# %%
settings_str = """
globals:
  seed: 1213
  device: cpu
  num_epochs: 20
  output_dir: training_output_v4/
  use_fold: 0
  target_sr: 32000

dataset:
  name: SpectrogramDataset
  params:
    img_size: 224
    melspectrogram_parameters:
      n_mels: 128
      fmin: 20
      fmax: 16000
    
split:
  name: StratifiedKFold
  params:
    n_splits: 5
    random_state: 42
    shuffle: True

loader:
  train:
    batch_size: 20
    shuffle: True
    num_workers: 0
    pin_memory: True
    drop_last: True
  val:
    batch_size: 20
    shuffle: False
    num_workers: 0
    pin_memory: True
    drop_last: False

model:
  name: resnest50_fast_1s1x64d
  params:
    pretrained: True
    n_classes: 5

loss:
  name: CrossEntropyLoss
  params: {}

optimizer:
  name: Adam
  params:
    lr: 0.001

scheduler:
  name: CosineAnnealingLR
  params:
    T_max: 10
"""
settings = yaml.safe_load(settings_str)

# %% [markdown]
# ### preprocess audio data

# %%
def resample(ebird_code: str,filename: str, target_sr: int):    
    audio_dir = TRAIN_AUDIO_DIR
    resample_dir = TRAIN_RESAMPLED_DIR
    ebird_dir = resample_dir / ebird_code
    
    try:
        y, _ = librosa.load(
            audio_dir / ebird_code / filename,
            sr=target_sr, mono=True, res_type="kaiser_fast")

        filename = filename.replace(".mp3", ".wav")
        sf.write(ebird_dir / filename, y, samplerate=target_sr)
    except Exception as e:
        print(e)
        with open("skipped.txt", "a") as f:
            file_path = str(audio_dir / ebird_code / filename)
            f.write(file_path + "\n")

# %%
keys = set(train.ebird_code)
values = np.arange(0, len(keys))
BIRD_CODE  = dict(zip(sorted(keys), values))
INV_BIRD_CODE = {v: k for k, v in BIRD_CODE.items()}

# %%
PERIOD = 5

def mono_to_color(
    X: np.ndarray, mean=None, std=None,
    norm_max=None, norm_min=None, eps=1e-6
):
    # Stack X as [X,X,X]
    X = np.stack([X, X, X], axis=-1)

    # Standardize
    mean = mean or X.mean()
    X = X - mean
    std = std or X.std()
    Xstd = X / (std + eps)
    _min, _max = Xstd.min(), Xstd.max()
    norm_max = norm_max or _max
    norm_min = norm_min or _min
    if (_max - _min) > eps:
        # Normalize to [0, 255]
        V = Xstd
        V[V < norm_min] = norm_min
        V[V > norm_max] = norm_max
        V = 255 * (V - norm_min) / (norm_max - norm_min)
        V = V.astype(np.uint8)
    else:
        # Just zero
        V = np.zeros_like(Xstd, dtype=np.uint8)
    return V

class SpectrogramDataset(data.Dataset):
    def __init__(
        self,
        file_list: tp.List[tp.List[str]], img_size=224,
        waveform_transforms=None, spectrogram_transforms=None, melspectrogram_parameters={}
    ):
        self.file_list = file_list  # list of list: [file_path, ebird_code]
        self.img_size = img_size
        self.waveform_transforms = waveform_transforms
        self.spectrogram_transforms = spectrogram_transforms
        self.melspectrogram_parameters = melspectrogram_parameters

    def __len__(self):
        return len(self.file_list)

    def __getitem__(self, idx: int):
        wav_path, ebird_code = self.file_list[idx]

        y, sr = sf.read(wav_path)

        if self.waveform_transforms:
            y = self.waveform_transforms(y)
        else:
            len_y = len(y)
            effective_length = sr * PERIOD
            if len_y < effective_length:
                new_y = np.zeros(effective_length, dtype=y.dtype)
                start = np.random.randint(effective_length - len_y)
                new_y[start:start + len_y] = y
                y = new_y.astype(np.float32)
            elif len_y > effective_length:
                start = np.random.randint(len_y - effective_length)
                y = y[start:start + effective_length].astype(np.float32)
            else:
                y = y.astype(np.float32)

        melspec = librosa.feature.melspectrogram(y, sr=sr, **self.melspectrogram_parameters)
        melspec = librosa.power_to_db(melspec).astype(np.float32)

        if self.spectrogram_transforms:
            melspec = self.spectrogram_transforms(melspec)
        else:
            pass

        image = mono_to_color(melspec)
        height, width, _ = image.shape
        image = cv2.resize(image, (int(width * self.img_size / height), self.img_size))
        image = np.moveaxis(image, 2, 0)
        image = (image / 255.0).astype(np.float32)

#         labels = np.zeros(len(BIRD_CODE), dtype="i")
        labels = np.zeros(len(BIRD_CODE), dtype="f")
        labels[BIRD_CODE[ebird_code]] = 1

        return image, labels

# %% [markdown]
# ### Train Utility

# %%
def get_loaders_for_training(
    args_dataset: tp.Dict, args_loader: tp.Dict,
    train_file_list: tp.List[str], val_file_list: tp.List[str]
):
    # # make dataset
    train_dataset = SpectrogramDataset(train_file_list, **args_dataset)
    val_dataset = SpectrogramDataset(val_file_list, **args_dataset)
    # # make dataloader
    train_loader = data.DataLoader(train_dataset, **args_loader["train"])
    val_loader = data.DataLoader(val_dataset, **args_loader["val"])
    return train_loader, val_loader

def get_model(args: tp.Dict):
    model =getattr(resnest_torch, args["name"])(pretrained=args["params"]["pretrained"])
    del model.fc
    # # use the same head as the baseline notebook.
    model.fc = nn.Sequential(
        nn.Linear(2048, 1024), nn.ReLU(), nn.Dropout(p=0.2),
        nn.Linear(1024, 1024), nn.ReLU(), nn.Dropout(p=0.2),
        nn.Linear(1024, args["params"]["n_classes"]))
    
    return model

# %%
def train_loop(
    manager, args, model, device,
    train_loader, optimizer, scheduler, loss_func
):
    """Run minibatch training loop"""
    while not manager.stop_trigger:
        model.train()
        for batch_idx, (data, target) in enumerate(train_loader):
            with manager.run_iteration():
                data, target = data.to(device), target.to(device)
                target = torch.argmax(target, axis=-1)
                optimizer.zero_grad()
                output = model(data)
                loss = loss_func(output, target) # Loss: CrossEntropy
                ppe.reporting.report({'train/loss': loss.item()})
                loss.backward()
                optimizer.step()
        scheduler.step()  # <- call at the end of each epoch
        

def eval_for_batch(
    args, model, device,
    data, target, loss_func, eval_func_dict={}
):
    """
    Run evaliation for valid
    
    This function is applied to each batch of val loader.
    """
    model.eval()
    data, target = data.to(device), target.to(device)
    output = model(data)
    # Final result will be average of averages of the same size
    target = torch.argmax(target, axis=-1) # From 2D to 1D
    val_loss = loss_func(output, target).item()
    ppe.reporting.report({'val/loss': val_loss})
    
    for eval_name, eval_func in eval_func_dict.items():
        eval_value = eval_func(output, target).item()
        ppe.reporting.report({"val/{}".format(eval_aame): eval_value})
        
    print(output.shape, target.shape)

# %%
def set_extensions(
    manager, args, model, device, test_loader, optimizer, evaluator,
    loss_func, eval_func_dict={}
):
    """set extensions for PPE"""
        
    my_extensions = [
        # # observe, report
        ppe_extensions.observe_lr(optimizer=optimizer),
        # ppe_extensions.ParameterStatistics(model, prefix='model'),
        # ppe_extensions.VariableStatisticsPlot(model),
        ppe_extensions.LogReport(),
        ppe_extensions.IgniteEvaluator(
            evaluator, test_loader, model, progress_bar=True),
        ppe_extensions.PlotReport(['train/loss', 'val/loss'], 'epoch', filename='loss.png'),
        ppe_extensions.PlotReport(['lr',], 'epoch', filename='lr.png'),
        ppe_extensions.PrintReport([
            'epoch', 'iteration', 'lr', 'train/loss', 'val/loss','val/acc', "elapsed_time"]),
#         ppe_extensions.ProgressBar(update_interval=100),

        # # evaluation
        (
            ppe_extensions.Evaluator(
                test_loader, model,
                eval_func=lambda data, target:
                    eval_for_batch(args, model, device, data, target, loss_func, eval_func_dict),
                progress_bar=True),
            (1, "epoch"),
        ),
        # # save model snapshot.
        (
            ppe_extensions.snapshot(
                target=model, filename="snapshot_epoch_{.updater.epoch}.pth"),
            ppe.training.triggers.MinValueTrigger(key="val/loss", trigger=(1, 'epoch'))
        ),
    ]
           
    # # set extensions to manager
    for ext in my_extensions:
        if isinstance(ext, tuple):
            manager.extend(ext[0], trigger=ext[1])
        else:
            manager.extend(ext)
        
    return manager

# %% [markdown]
# ### Train

# %% [markdown]
# #### get wav file path

# %%
train=train.rename(columns={'filename':'resampled_filename'})

# %%
train.resampled_filename=[filename.replace(".mp3", ".wav") for filename in train.resampled_filename]

# %%
tmp_list = []
for ebird_d  in TRAIN_RESAMPLED_AUDIO_DIRS.iterdir():
    if os.path.split(ebird_d)[1]=='.DS_Store':
        continue

    for wav_f in ebird_d.iterdir():
        tmp_list.append([ebird_d.name, wav_f.name, wav_f.as_posix()])

train_wav_path_exist = pd.DataFrame(
    tmp_list, columns=["ebird_code", "resampled_filename", "file_path"])

del tmp_list

train_all = pd.merge(train, train_wav_path_exist, on=["ebird_code", "resampled_filename"], how="inner")


print(train.shape)
print(train_wav_path_exist.shape)
print(train_all.shape)
# Out:
# (500, 36)
# (500, 3)
# (500, 37)

# %% [markdown]
# ### split data

# %%
skf = StratifiedKFold(**settings["split"]["params"])

train_all["fold"] = -1
for fold_id, (train_index, val_index) in enumerate(skf.split(train_all, train_all["ebird_code"])):
    train_all.iloc[val_index, -1] = fold_id
    
# # check the propotion
fold_proportion = pd.pivot_table(train_all, index="ebird_code", columns="fold", values="xc_id", aggfunc=len)
print(fold_proportion.shape)
# Out:
# (5, 5)

# %%
use_fold = settings["globals"]["use_fold"]
train_file_list = train_all.query("fold != @use_fold")[["file_path", "ebird_code"]].values.tolist()
val_file_list = train_all.query("fold == @use_fold")[["file_path", "ebird_code"]].values.tolist()

print("[fold {}] train: {}, val: {}".format(use_fold, len(train_file_list), len(val_file_list)))
# Out:
# [fold 0] train: 400, val: 100

# %%
### run training

# %%
set_seed(settings["globals"]["seed"])
device = torch.device(settings["globals"]["device"])
output_dir = Path(settings["globals"]["output_dir"])

# # # get loader
train_loader, val_loader = get_loaders_for_training(
    settings["dataset"]["params"], settings["loader"], train_file_list, val_file_list)

# # # get model
model = get_model(settings["model"])
model = model.to(device)

# # # get optimizer
optimizer = getattr(
    torch.optim, settings["optimizer"]["name"]
)(model.parameters(), **settings["optimizer"]["params"])

# # # get scheduler
scheduler = getattr(
    torch.optim.lr_scheduler, settings["scheduler"]["name"]
)(optimizer, **settings["scheduler"]["params"])

# # # get loss
loss_func = getattr(nn, settings["loss"]["name"])(**settings["loss"]["params"])

# get evaluator
evaluator = create_supervised_evaluator(
    model,
    metrics={'acc': Accuracy(is_multilabel=True)},
    device=device,
    output_transform=lambda x,y,y_pred: (torch.FloatTensor(y_pred.shape).zero_().scatter_(0,  torch.argmax(y_pred, 0,keepdim=True), 1),
                                         y))

      
# # # create training manager
trigger = None


manager = ppe.training.ExtensionsManager(
    model, optimizer, settings["globals"]["num_epochs"],
    iters_per_epoch=len(train_loader),
    stop_trigger=trigger,
    out_dir=output_dir
)

# # # set manager extensions
manager = set_extensions(
    manager, settings, model, device,
    val_loader, optimizer,evaluator ,loss_func,
)

# %%
# # runtraining with lr = 0.001

train_loop(
    manager, settings, model, device,
    train_loader, optimizer, scheduler, loss_func)
# Out:
# epoch       iteration   lr          train/loss  val/loss    val/acc     elapsed_time
# validation [##################################################] 100.00%
#          1 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([40, 2]) torch.Size([40, 2])
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# 1           3           0.001       0.74669     0.674114    0.025       255.05
# validation [##################################################] 100.00%
#          1 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([40, 2]) torch.Size([40, 2])
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# 2           6           0.000975528  0.615475    1.44083     0.05        528.247
# validation [##################################################] 100.00%
#          1 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([40, 2]) torch.Size([40, 2])
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# 3           9           0.000904508  0.475029    1.51582     0.05        799.43
# validation [##################################################] 100.00%
#          1 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# Engine run is terminating due to exception:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-361-ee6e2868fb1f> in <module>
#       3 train_loop(
#       4     manager, settings, model, device,
# ----> 5     train_loader, optimizer, scheduler, loss_func)
#
# <ipython-input-344-f478f19f15f9> in train_loop(manager, args, model, device, train_loader, optimizer, scheduler, loss_func)
#      14                 ppe.reporting.report({'train/loss': loss.item()})
#      15                 loss.backward()
# ---> 16                 optimizer.step()
#      17         scheduler.step()  # <- call at the end of each epoch
#      18
#
# ~/opt/anaconda3/lib/python3.7/contextlib.py in __exit__(self, type, value, traceback)
#     117         if type is None:
#     118             try:
# --> 119                 next(self.gen)
#     120             except StopIteration:
#     121                 return False
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pytorch_pfn_extras/training/manager.py in run_iteration(self, step_optimizers)
#     438                 # to keep the semantics
#     439                 self.iteration += 1
# --> 440                 self.run_extensions()
#     441
#     442         if self._internal_stop_trigger(self):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pytorch_pfn_extras/training/manager.py in run_extensions(self)
#     305                     to_run.append(entry.extension)
#     306                 else:
# --> 307                     entry.extension(self)
#     308         for extension in to_run:
#     309             extension(self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pytorch_pfn_extras/training/extensions/evaluator.py in __call__(self, manager)
#     166         with reporter:
#     167             with torch.no_grad():
# --> 168                 result = self.evaluate()
#     169
#     170         reporting.report(result)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pytorch_pfn_extras/training/extensions/evaluator.py in evaluate(self)
#     338         if self._progress_bar:
#     339             self.pbar = _IteratorProgressBar(iterator=self.progress)
# --> 340         self.evaluator.run(iterator)
#     341         if self._progress_bar:
#     342             self.pbar.close()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/ignite/engine/engine.py in run(self, data, max_epochs, epoch_length, seed)
#     699
#     700         self.state.dataloader = data
# --> 701         return self._internal_run()
#     702
#     703     @staticmethod
#
# ~/opt/anaconda3/lib/python3.7/site-packages/ignite/engine/engine.py in _internal_run(self)
#     772             self._dataloader_iter = None
#     773             self.logger.error(f"Engine run is terminating due to exception: {e}")
# --> 774             self._handle_exception(e)
#     775
#     776         self._dataloader_iter = None
#
# ~/opt/anaconda3/lib/python3.7/site-packages/ignite/engine/engine.py in _handle_exception(self, e)
#     467             self._fire_event(Events.EXCEPTION_RAISED, e)
#     468         else:
# --> 469             raise e
#     470
#     471     @property
#
# ~/opt/anaconda3/lib/python3.7/site-packages/ignite/engine/engine.py in _internal_run(self)
#     742                     self._setup_engine()
#     743
# --> 744                 time_taken = self._run_once_on_dataset()
#     745                 # time is available for handlers but must be update after fire
#     746                 self.state.times[Events.EPOCH_COMPLETED.name] = time_taken
#
# ~/opt/anaconda3/lib/python3.7/site-packages/ignite/engine/engine.py in _run_once_on_dataset(self)
#     832                 self.state.iteration += 1
#     833                 self._fire_event(Events.ITERATION_STARTED)
# --> 834                 self.state.output = self._process_function(self, self.state.batch)
#     835                 self._fire_event(Events.ITERATION_COMPLETED)
#     836
#
# ~/opt/anaconda3/lib/python3.7/site-packages/ignite/engine/__init__.py in evaluate_step(engine, batch)
#     457         with torch.no_grad():
#     458             x, y = prepare_batch(batch, device=device, non_blocking=non_blocking)
# --> 459             y_pred = model(x)
#     460             return output_transform(x, y, y_pred)
#     461
#
# ~/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/opt/anaconda3/lib/python3.7/site-packages/resnest/torch/models/resnet.py in forward(self, x)
#     304
#     305         x = self.layer1(x)
# --> 306         x = self.layer2(x)
#     307         x = self.layer3(x)
#     308         x = self.layer4(x)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/container.py in forward(self, input)
#     117     def forward(self, input):
#     118         for module in self:
# --> 119             input = module(input)
#     120         return input
#     121
#
# ~/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/opt/anaconda3/lib/python3.7/site-packages/resnest/torch/models/resnet.py in forward(self, x)
#     116             out = self.avd_layer(out)
#     117
# --> 118         out = self.conv2(out)
#     119         if self.radix == 0:
#     120             out = self.bn2(out)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/opt/anaconda3/lib/python3.7/site-packages/resnest/torch/models/splat.py in forward(self, x)
#      50
#      51     def forward(self, x):
# ---> 52         x = self.conv(x)
#      53         if self.use_bn:
#      54             x = self.bn0(x)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     397
#     398     def forward(self, input: Tensor) -> Tensor:
# --> 399         return self._conv_forward(input, self.weight, self.bias)
#     400
#     401 class Conv3d(_ConvNd):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight, bias)
#     394                             _pair(0), self.dilation, self.groups)
#     395         return F.conv2d(input, weight, bias, self.stride,
# --> 396                         self.padding, self.dilation, self.groups)
#     397
#     398     def forward(self, input: Tensor) -> Tensor:
#
# KeyboardInterrupt:

# %%
set_seed(settings["globals"]["seed"])
device = torch.device(settings["globals"]["device"])
output_dir = Path(settings["globals"]["output_dir"])

# # # get loader
train_loader, val_loader = get_loaders_for_training(
    settings["dataset"]["params"], settings["loader"], train_file_list, val_file_list)

# # # get model
model = get_model(settings["model"])
model = model.to(device)

# # # get optimizer
optimizer = getattr(
    torch.optim, settings["optimizer"]["name"]
)(model.parameters(), **settings["optimizer"]["params"])

# # # get scheduler
scheduler = getattr(
    torch.optim.lr_scheduler, settings["scheduler"]["name"]
)(optimizer, **settings["scheduler"]["params"])

# # # get loss
loss_func = getattr(nn, settings["loss"]["name"])(**settings["loss"]["params"])

# # # create training manager
trigger = None


my_extensions = [
    extensions.LogReport(),
    extensions.ProgressBar(),
    extensions.observe_lr(optimizer=optimizer),
    extensions.Evaluator(
        val_loader, model,
                progress_bar=True),
    extensions.PlotReport(
    ['train/loss', 'val/loss'], 'epoch', filename='loss.png'),
    extensions.PrintReport(['epoch', 'iteration',
                                'train/loss', 'lr', 'model/fc2.bias/grad/min',
                                'val/loss', 'val/acc']),
    extensions.snapshot(),
]



manager = ppe.training.ExtensionsManager(
    model, optimizer, settings["globals"]["num_epochs"],
    iters_per_epoch=len(train_loader),
    stop_trigger=trigger,
    out_dir=output_dir
)

# # # set manager extensions
manager = set_extensions(
    manager, settings, model, device,
    val_loader, optimizer, loss_func,
    
)

# %%
# # runtraining with lr = 0.001 
# num_epochs: 20
# batch_size: 20
train_loop(
    manager, settings, model, device,
    train_loader, optimizer, scheduler, loss_func)
# Out:
# epoch       iteration   lr          train/loss  val/loss    elapsed_time
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [#########################.........................] 50.00%
#          1 iterations
#    0.13202 iters/sec. Estimated time to finish: 0:00:07.574816.
# 1           8           0.001       0.717864    3.07181     191.299
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [#########################.........................] 50.00%
#          1 iterations
#    0.13176 iters/sec. Estimated time to finish: 0:00:07.589575.
# 2           16          0.000975528  0.358309    5.29726     385.553
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [#########################.........................] 50.00%
#          1 iterations
#    0.13989 iters/sec. Estimated time to finish: 0:00:07.148575.
# 3           24          0.000904508  0.342709    0.610762    573.195
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [#########################.........................] 50.00%
#          1 iterations
#    0.14197 iters/sec. Estimated time to finish: 0:00:07.043584.
# 4           32          0.000793893  0.557742    1.70692     759.341
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [#########################.........................] 50.00%
#          1 iterations
#    0.13285 iters/sec. Estimated time to finish: 0:00:07.527161.
# 5           40          0.000654508  0.308036    0.289838    944.294
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [#########################.........................] 50.00%
#          1 iterations
#    0.13662 iters/sec. Estimated time to finish: 0:00:07.319537.
# 6           48          0.0005      0.279819    0.112504    1138.33
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [#########################.........................] 50.00%
#          1 iterations
#    0.13452 iters/sec. Estimated time to finish: 0:00:07.433962.
# 7           56          0.000345492  0.159882    0.273626    1330.87
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [#########################.........................] 50.00%
#          1 iterations
#    0.13106 iters/sec. Estimated time to finish: 0:00:07.630067.
# 8           64          0.000206107  0.140134    0.242746    1531.61
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [#########################.........................] 50.00%
#          1 iterations
#    0.12859 iters/sec. Estimated time to finish: 0:00:07.776796.
# 9           72          9.54915e-05  0.0984292   0.179446    1735.58
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [#########################.........................] 50.00%
#          1 iterations
#    0.11583 iters/sec. Estimated time to finish: 0:00:08.633682.
# 10          80          2.44717e-05  0.110801    0.162791    1952.72
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [#########################.........................] 50.00%
#          1 iterations
#    0.12013 iters/sec. Estimated time to finish: 0:00:08.324654.
# 11          88          0           0.184241    0.180673    2171.82
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [#########################.........................] 50.00%
#          1 iterations
#    0.12526 iters/sec. Estimated time to finish: 0:00:07.983079.
# 12          96          2.44717e-05  0.093705    0.248439    2392.96
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [#########################.........................] 50.00%
#          1 iterations
#    0.11996 iters/sec. Estimated time to finish: 0:00:08.336356.
# 13          104         9.54915e-05  0.0741542   0.377304    2628.68
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [#########################.........................] 50.00%
#          1 iterations
#    0.11346 iters/sec. Estimated time to finish: 0:00:08.813895.
# 14          112         0.000206107  0.11092     0.326101    2851.52
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [#########################.........................] 50.00%
#          1 iterations
#    0.11938 iters/sec. Estimated time to finish: 0:00:08.376547.
# 15          120         0.000345492  0.142045    0.479832    3079.24
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [#########################.........................] 50.00%
#          1 iterations
#    0.11382 iters/sec. Estimated time to finish: 0:00:08.786013.
# 16          128         0.0005      0.200037    0.362039    3303.13
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [#########################.........................] 50.00%
#          1 iterations
#    0.12039 iters/sec. Estimated time to finish: 0:00:08.306304.
# 17          136         0.000654508  0.223669    0.248534    3521.47
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [#########################.........................] 50.00%
#          1 iterations
#    0.13411 iters/sec. Estimated time to finish: 0:00:07.456718.
# 18          144         0.000793893  0.130926    0.390027    3732.07
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [#########################.........................] 50.00%
#          1 iterations
#    0.13126 iters/sec. Estimated time to finish: 0:00:07.618435.
# 19          152         0.000904508  0.108355    0.659181    3930.43
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [#########################.........................] 50.00%
#          1 iterations
#    0.12663 iters/sec. Estimated time to finish: 0:00:07.897164.
# 20          160         0.000975528  0.227473    9.98727     4130.31

# %%
set_seed(settings["globals"]["seed"])
device = torch.device(settings["globals"]["device"])
output_dir = Path(settings["globals"]["output_dir"])

# # # get loader
train_loader, val_loader = get_loaders_for_training(
    settings["dataset"]["params"], settings["loader"], train_file_list, val_file_list)

# # # get model
model = get_model(settings["model"])
model = model.to(device)

# # # get optimizer
optimizer = getattr(
    torch.optim, settings["optimizer"]["name"]
)(model.parameters(), **settings["optimizer"]["params"])

# # # get scheduler
scheduler = getattr(
    torch.optim.lr_scheduler, settings["scheduler"]["name"]
)(optimizer, **settings["scheduler"]["params"])

# # # get loss
loss_func = getattr(nn, settings["loss"]["name"])(**settings["loss"]["params"])

# # # create training manager
trigger = None


my_extensions = [
    extensions.LogReport(),
    extensions.ProgressBar(),
    extensions.observe_lr(optimizer=optimizer),
    extensions.Evaluator(
        val_loader, model,
                progress_bar=True),
    extensions.PlotReport(
    ['train/loss', 'val/loss'], 'epoch', filename='loss.png'),
    extensions.PrintReport(['epoch', 'iteration',
                                'train/loss', 'lr', 'model/fc2.bias/grad/min',
                                'val/loss', 'val/acc']),
    extensions.snapshot(),
]



manager = ppe.training.ExtensionsManager(
    model, optimizer, settings["globals"]["num_epochs"],
    iters_per_epoch=len(train_loader),
    stop_trigger=trigger,
    out_dir=output_dir
)

# # # set manager extensions
manager = set_extensions(
    manager, settings, model, device,
    val_loader, optimizer, loss_func,
)

# %%
# # runtraining with lr = 0.001 
# num_epochs: 20
# batch_size: 20
train_loop(
    manager, settings, model, device,
    train_loader, optimizer, scheduler, loss_func)
# Out:
# epoch       iteration   lr          train/loss  val/loss    val/acc     elapsed_time
# validation [#########################.........................] 50.00%
#          1 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [##################################################] 100.00%
#          2 iterations
#    0.11653 iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 2]) torch.Size([20, 2])
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 2]) torch.Size([20, 2])
# validation [#########################.........................] 50.00%
#          1 iterations
#    0.11989 iters/sec. Estimated time to finish: 0:00:08.341182.
# 1           8           0.001       0.717864    3.28342     0.05        248.651
# validation [#########################.........................] 50.00%
#          1 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [##################################################] 100.00%
#          2 iterations
#    0.10572 iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 2]) torch.Size([20, 2])
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 2]) torch.Size([20, 2])
# validation [#########################.........................] 50.00%
#          1 iterations
#    0.11501 iters/sec. Estimated time to finish: 0:00:08.694619.
# 2           16          0.000975528  0.503074    16.6877     0.05        508.564
# validation [#########################.........................] 50.00%
#          1 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [##################################################] 100.00%
#          2 iterations
#    0.10012 iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 2]) torch.Size([20, 2])
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 2]) torch.Size([20, 2])
# validation [#########################.........................] 50.00%
#          1 iterations
#    0.10507 iters/sec. Estimated time to finish: 0:00:09.517820.
# 3           24          0.000904508  0.270637    0.749153    0.05        764.364
# validation [#########################.........................] 50.00%
#          1 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [##################################################] 100.00%
#          2 iterations
#    0.11774 iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 2]) torch.Size([20, 2])
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 2]) torch.Size([20, 2])
# validation [#########################.........................] 50.00%
#          1 iterations
#    0.12139 iters/sec. Estimated time to finish: 0:00:08.238127.
# 4           32          0.000793893  0.379248    2.96678     0.05        1010.77
# validation [#########################.........................] 50.00%
#          1 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [##################################################] 100.00%
#          2 iterations
#    0.12361 iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 2]) torch.Size([20, 2])
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 2]) torch.Size([20, 2])
# validation [#########################.........................] 50.00%
#          1 iterations
#    0.11806 iters/sec. Estimated time to finish: 0:00:08.469975.
# 5           40          0.000654508  0.382853    1.81742     0.05        1243.19
# validation [#########################.........................] 50.00%
#          1 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [##################################################] 100.00%
#          2 iterations
#    0.10936 iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 2]) torch.Size([20, 2])
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 2]) torch.Size([20, 2])
# validation [#########################.........................] 50.00%
#          1 iterations
#    0.11074 iters/sec. Estimated time to finish: 0:00:09.030463.
# 6           48          0.0005      0.365667    0.397563    0.05        1481.1
# validation [#########################.........................] 50.00%
#          1 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [##################################################] 100.00%
#          2 iterations
#    0.11079 iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 2]) torch.Size([20, 2])
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 2]) torch.Size([20, 2])
# validation [#########################.........................] 50.00%
#          1 iterations
#    0.11983 iters/sec. Estimated time to finish: 0:00:08.345495.
# 7           56          0.000345492  0.373983    0.301621    0.05        1737.94
# validation [#########################.........................] 50.00%
#          1 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [##################################################] 100.00%
#          2 iterations
#     0.1174 iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 2]) torch.Size([20, 2])
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 2]) torch.Size([20, 2])
# validation [#########################.........................] 50.00%
#          1 iterations
#    0.11832 iters/sec. Estimated time to finish: 0:00:08.451398.
# 8           64          0.000206107  0.245683    0.341064    0.05        1980.68
# validation [#########################.........................] 50.00%
#          1 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [##################################################] 100.00%
#          2 iterations
#    0.12035 iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 2]) torch.Size([20, 2])
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 2]) torch.Size([20, 2])
# validation [#########################.........................] 50.00%
#          1 iterations
#    0.12159 iters/sec. Estimated time to finish: 0:00:08.224157.
# 9           72          9.54915e-05  0.182911    0.292869    0.05        2214.99
# validation [#########################.........................] 50.00%
#          1 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [##################################################] 100.00%
#          2 iterations
#    0.10763 iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 2]) torch.Size([20, 2])
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 2]) torch.Size([20, 2])
# validation [#########################.........................] 50.00%
#          1 iterations
#     0.1167 iters/sec. Estimated time to finish: 0:00:08.569251.
# 10          80          2.44717e-05  0.181731    0.307592    0.05        2459.61
# validation [#########################.........................] 50.00%
#          1 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [##################################################] 100.00%
#          2 iterations
#    0.11618 iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 2]) torch.Size([20, 2])
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 2]) torch.Size([20, 2])
# validation [#########################.........................] 50.00%
#          1 iterations
#    0.10715 iters/sec. Estimated time to finish: 0:00:09.333082.
# 11          88          0           0.182874    0.192565    0.05        2703.7
# validation [#########################.........................] 50.00%
#          1 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [##################################################] 100.00%
#          2 iterations
#   0.082964 iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 2]) torch.Size([20, 2])
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 2]) torch.Size([20, 2])
# validation [#########################.........................] 50.00%
#          1 iterations
#   0.079294 iters/sec. Estimated time to finish: 0:00:12.611255.
# 12          96          2.44717e-05  0.160234    0.241253    0.05        3003.49
# validation [#########################.........................] 50.00%
#          1 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [##################################################] 100.00%
#          2 iterations
#    0.07034 iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 2]) torch.Size([20, 2])
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 2]) torch.Size([20, 2])
# validation [#########################.........................] 50.00%
#          1 iterations
#    0.07114 iters/sec. Estimated time to finish: 0:00:14.056751.
# 13          104         9.54915e-05  0.127872    0.261321    0.05        3375.67
# validation [#########################.........................] 50.00%
#          1 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [##################################################] 100.00%
#          2 iterations
#   0.082233 iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 2]) torch.Size([20, 2])
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 2]) torch.Size([20, 2])
# validation [#########################.........................] 50.00%
#          1 iterations
#   0.084289 iters/sec. Estimated time to finish: 0:00:11.863945.
# 14          112         0.000206107  0.121652    0.181802    0.05        3761.65
# validation [#########################.........................] 50.00%
#          1 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# Engine run is terminating due to exception:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pytorch_pfn_extras/training/manager.py in run_iteration(self, step_optimizers)
#     431                     self._optimizers[name].zero_grad()
# --> 432                 yield
#     433                 for name in step_optimizers_names:
#
# <ipython-input-344-f478f19f15f9> in train_loop(manager, args, model, device, train_loader, optimizer, scheduler, loss_func)
#      14                 ppe.reporting.report({'train/loss': loss.item()})
# ---> 15                 loss.backward()
#      16                 optimizer.step()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     244                 inputs=inputs)
# --> 245         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     246
#
# ~/opt/anaconda3/lib/python3.7/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     146         tensors, grad_tensors_, retain_graph, create_graph, inputs,
# --> 147         allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
#     148
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-365-bb3daf804dd8> in <module>
#       4 train_loop(
#       5     manager, settings, model, device,
# ----> 6     train_loader, optimizer, scheduler, loss_func)
#
# <ipython-input-344-f478f19f15f9> in train_loop(manager, args, model, device, train_loader, optimizer, scheduler, loss_func)
#      14                 ppe.reporting.report({'train/loss': loss.item()})
#      15                 loss.backward()
# ---> 16                 optimizer.step()
#      17         scheduler.step()  # <- call at the end of each epoch
#      18
#
# ~/opt/anaconda3/lib/python3.7/contextlib.py in __exit__(self, type, value, traceback)
#     128                 value = type()
#     129             try:
# --> 130                 self.gen.throw(type, value, traceback)
#     131             except StopIteration as exc:
#     132                 # Suppress StopIteration *unless* it's the same exception that
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pytorch_pfn_extras/training/manager.py in run_iteration(self, step_optimizers)
#     438                 # to keep the semantics
#     439                 self.iteration += 1
# --> 440                 self.run_extensions()
#     441
#     442         if self._internal_stop_trigger(self):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pytorch_pfn_extras/training/manager.py in run_extensions(self)
#     305                     to_run.append(entry.extension)
#     306                 else:
# --> 307                     entry.extension(self)
#     308         for extension in to_run:
#     309             extension(self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pytorch_pfn_extras/training/extensions/evaluator.py in __call__(self, manager)
#     166         with reporter:
#     167             with torch.no_grad():
# --> 168                 result = self.evaluate()
#     169
#     170         reporting.report(result)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pytorch_pfn_extras/training/extensions/evaluator.py in evaluate(self)
#     338         if self._progress_bar:
#     339             self.pbar = _IteratorProgressBar(iterator=self.progress)
# --> 340         self.evaluator.run(iterator)
#     341         if self._progress_bar:
#     342             self.pbar.close()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/ignite/engine/engine.py in run(self, data, max_epochs, epoch_length, seed)
#     699
#     700         self.state.dataloader = data
# --> 701         return self._internal_run()
#     702
#     703     @staticmethod
#
# ~/opt/anaconda3/lib/python3.7/site-packages/ignite/engine/engine.py in _internal_run(self)
#     772             self._dataloader_iter = None
#     773             self.logger.error(f"Engine run is terminating due to exception: {e}")
# --> 774             self._handle_exception(e)
#     775
#     776         self._dataloader_iter = None
#
# ~/opt/anaconda3/lib/python3.7/site-packages/ignite/engine/engine.py in _handle_exception(self, e)
#     467             self._fire_event(Events.EXCEPTION_RAISED, e)
#     468         else:
# --> 469             raise e
#     470
#     471     @property
#
# ~/opt/anaconda3/lib/python3.7/site-packages/ignite/engine/engine.py in _internal_run(self)
#     742                     self._setup_engine()
#     743
# --> 744                 time_taken = self._run_once_on_dataset()
#     745                 # time is available for handlers but must be update after fire
#     746                 self.state.times[Events.EPOCH_COMPLETED.name] = time_taken
#
# ~/opt/anaconda3/lib/python3.7/site-packages/ignite/engine/engine.py in _run_once_on_dataset(self)
#     832                 self.state.iteration += 1
#     833                 self._fire_event(Events.ITERATION_STARTED)
# --> 834                 self.state.output = self._process_function(self, self.state.batch)
#     835                 self._fire_event(Events.ITERATION_COMPLETED)
#     836
#
# ~/opt/anaconda3/lib/python3.7/site-packages/ignite/engine/__init__.py in evaluate_step(engine, batch)
#     457         with torch.no_grad():
#     458             x, y = prepare_batch(batch, device=device, non_blocking=non_blocking)
# --> 459             y_pred = model(x)
#     460             return output_transform(x, y, y_pred)
#     461
#
# ~/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/opt/anaconda3/lib/python3.7/site-packages/resnest/torch/models/resnet.py in forward(self, x)
#     306         x = self.layer2(x)
#     307         x = self.layer3(x)
# --> 308         x = self.layer4(x)
#     309
#     310         x = self.avgpool(x)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/container.py in forward(self, input)
#     117     def forward(self, input):
#     118         for module in self:
# --> 119             input = module(input)
#     120         return input
#     121
#
# ~/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/opt/anaconda3/lib/python3.7/site-packages/resnest/torch/models/resnet.py in forward(self, x)
#     107         residual = x
#     108
# --> 109         out = self.conv1(x)
#     110         out = self.bn1(out)
#     111         if self.dropblock_prob > 0.0:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     397
#     398     def forward(self, input: Tensor) -> Tensor:
# --> 399         return self._conv_forward(input, self.weight, self.bias)
#     400
#     401 class Conv3d(_ConvNd):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight, bias)
#     394                             _pair(0), self.dilation, self.groups)
#     395         return F.conv2d(input, weight, bias, self.stride,
# --> 396                         self.padding, self.dilation, self.groups)
#     397
#     398     def forward(self, input: Tensor) -> Tensor:
#
# KeyboardInterrupt:

# %%
# # runtraining with lr = 0.001 
# num_epochs: 20
# batch_size: 20
train_loop(
    manager, settings, model, device,
    train_loader, optimizer, scheduler, loss_func)
# Out:
# epoch       iteration   lr          train/loss  val/loss    val/acc     elapsed_time
# validation [##########........................................] 20.00%
#          1 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [####################..............................] 40.00%
#          2 iterations
#   0.094922 iters/sec. Estimated time to finish: 0:00:31.604885.
# validation [##############################....................] 60.00%
#          3 iterations
#   0.093546 iters/sec. Estimated time to finish: 0:00:21.379854.
# validation [########################################..........] 80.00%
#          4 iterations
#   0.094509 iters/sec. Estimated time to finish: 0:00:10.580972.
# validation [##################################################] 100.00%
#          5 iterations
#   0.095115 iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [##########........................................] 20.00%
#          1 iterations
#   0.097312 iters/sec. Estimated time to finish: 0:00:41.104844.
# torch.Size([20, 5]) torch.Size([20])
# validation [####################..............................] 40.00%
#          2 iterations
#   0.093578 iters/sec. Estimated time to finish: 0:00:32.058910.
# torch.Size([20, 5]) torch.Size([20])
# validation [##############################....................] 60.00%
#          3 iterations
#   0.092451 iters/sec. Estimated time to finish: 0:00:21.633102.
# torch.Size([20, 5]) torch.Size([20])
# validation [########################################..........] 80.00%
#          4 iterations
#   0.090766 iters/sec. Estimated time to finish: 0:00:11.017320.
# 1           20          0.001       1.56438     2.69847     0.02        796.796
# validation [##########........................................] 20.00%
#          1 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [####################..............................] 40.00%
#          2 iterations
#   0.082518 iters/sec. Estimated time to finish: 0:00:36.355692.
# validation [##############################....................] 60.00%
#          3 iterations
#   0.081128 iters/sec. Estimated time to finish: 0:00:24.652262.
# validation [########################################..........] 80.00%
#          4 iterations
#   0.082336 iters/sec. Estimated time to finish: 0:00:12.145326.
# validation [##################################################] 100.00%
#          5 iterations
#   0.082983 iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [##########........................................] 20.00%
#          1 iterations
#   0.087219 iters/sec. Estimated time to finish: 0:00:45.861515.
# torch.Size([20, 5]) torch.Size([20])
# validation [####################..............................] 40.00%
#          2 iterations
#   0.085051 iters/sec. Estimated time to finish: 0:00:35.272908.
# torch.Size([20, 5]) torch.Size([20])
# validation [##############################....................] 60.00%
#          3 iterations
#   0.085813 iters/sec. Estimated time to finish: 0:00:23.306537.
# torch.Size([20, 5]) torch.Size([20])
# validation [########################################..........] 80.00%
#          4 iterations
#    0.08776 iters/sec. Estimated time to finish: 0:00:11.394764.
# 2           40          0.000975528  1.3202      2.62684     0.01        1604.9
# validation [##########........................................] 20.00%
#          1 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [####################..............................] 40.00%
#          2 iterations
#   0.074239 iters/sec. Estimated time to finish: 0:00:40.410162.
# validation [##############################....................] 60.00%
#          3 iterations
#   0.073209 iters/sec. Estimated time to finish: 0:00:27.319126.
# validation [########################################..........] 80.00%
#          4 iterations
#   0.073766 iters/sec. Estimated time to finish: 0:00:13.556322.
# validation [##################################################] 100.00%
#          5 iterations
#   0.074819 iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [##########........................................] 20.00%
#          1 iterations
#   0.077967 iters/sec. Estimated time to finish: 0:00:51.304076.
# torch.Size([20, 5]) torch.Size([20])
# validation [####################..............................] 40.00%
#          2 iterations
#   0.077614 iters/sec. Estimated time to finish: 0:00:38.652834.
# torch.Size([20, 5]) torch.Size([20])
# validation [##############################....................] 60.00%
#          3 iterations
#   0.078927 iters/sec. Estimated time to finish: 0:00:25.339751.
# torch.Size([20, 5]) torch.Size([20])
# validation [########################################..........] 80.00%
#          4 iterations
#    0.08043 iters/sec. Estimated time to finish: 0:00:12.433160.
# 3           60          0.000904508  1.09914     1.50213     0.04        2424.91
# validation [##########........................................] 20.00%
#          1 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [####################..............................] 40.00%
#          2 iterations
#   0.074501 iters/sec. Estimated time to finish: 0:00:40.267731.
# validation [##############################....................] 60.00%
#          3 iterations
#   0.074543 iters/sec. Estimated time to finish: 0:00:26.830023.
# validation [########################################..........] 80.00%
#          4 iterations
#   0.075709 iters/sec. Estimated time to finish: 0:00:13.208404.
# validation [##################################################] 100.00%
#          5 iterations
#   0.077186 iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [##########........................................] 20.00%
#          1 iterations
#   0.081986 iters/sec. Estimated time to finish: 0:00:48.788541.
# torch.Size([20, 5]) torch.Size([20])
# validation [####################..............................] 40.00%
#          2 iterations
#   0.079834 iters/sec. Estimated time to finish: 0:00:37.577961.
# torch.Size([20, 5]) torch.Size([20])
# validation [##############################....................] 60.00%
#          3 iterations
#   0.079918 iters/sec. Estimated time to finish: 0:00:25.025671.
# torch.Size([20, 5]) torch.Size([20])
# validation [########################################..........] 80.00%
#          4 iterations
#    0.08029 iters/sec. Estimated time to finish: 0:00:12.454851.
# 4           80          0.000793893  1.13861     0.864423    0.05        3288.64
# validation [##########........................................] 20.00%
#          1 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [####################..............................] 40.00%
#          2 iterations
#    0.11786 iters/sec. Estimated time to finish: 0:00:25.454001.
# validation [##############################....................] 60.00%
#          3 iterations
#    0.11503 iters/sec. Estimated time to finish: 0:00:17.386525.
# validation [########################################..........] 80.00%
#          4 iterations
#    0.11535 iters/sec. Estimated time to finish: 0:00:08.669182.
# validation [##################################################] 100.00%
#          5 iterations
#    0.11612 iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [##########........................................] 20.00%
#          1 iterations
#      0.124 iters/sec. Estimated time to finish: 0:00:32.257384.
# torch.Size([20, 5]) torch.Size([20])
# validation [####################..............................] 40.00%
#          2 iterations
#    0.12128 iters/sec. Estimated time to finish: 0:00:24.736419.
# torch.Size([20, 5]) torch.Size([20])
# validation [##############################....................] 60.00%
#          3 iterations
#    0.12152 iters/sec. Estimated time to finish: 0:00:16.458207.
# torch.Size([20, 5]) torch.Size([20])
# validation [########################################..........] 80.00%
#          4 iterations
#    0.12201 iters/sec. Estimated time to finish: 0:00:08.196132.
# 5           100         0.000654508  0.985853    1.04002     0.04        4004.75
# validation [##########........................................] 20.00%
#          1 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [####################..............................] 40.00%
#          2 iterations
#    0.12894 iters/sec. Estimated time to finish: 0:00:23.267411.
# validation [##############################....................] 60.00%
#          3 iterations
#    0.12658 iters/sec. Estimated time to finish: 0:00:15.800620.
# validation [########################################..........] 80.00%
#          4 iterations
#    0.12763 iters/sec. Estimated time to finish: 0:00:07.835392.
# validation [##################################################] 100.00%
#          5 iterations
#    0.12855 iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [##########........................................] 20.00%
#          1 iterations
#    0.13218 iters/sec. Estimated time to finish: 0:00:30.261395.
# torch.Size([20, 5]) torch.Size([20])
# validation [####################..............................] 40.00%
#          2 iterations
#    0.12658 iters/sec. Estimated time to finish: 0:00:23.700822.
# torch.Size([20, 5]) torch.Size([20])
# validation [##############################....................] 60.00%
#          3 iterations
#    0.12587 iters/sec. Estimated time to finish: 0:00:15.889716.
# torch.Size([20, 5]) torch.Size([20])
# validation [########################################..........] 80.00%
#          4 iterations
#    0.12589 iters/sec. Estimated time to finish: 0:00:07.943525.
# 6           120         0.0005      0.861794    1.17249     0.05        4575.81
# validation [##########........................................] 20.00%
#          1 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [####################..............................] 40.00%
#          2 iterations
#    0.13214 iters/sec. Estimated time to finish: 0:00:22.702394.
# validation [##############################....................] 60.00%
#          3 iterations
#    0.12989 iters/sec. Estimated time to finish: 0:00:15.398140.
# validation [########################################..........] 80.00%
#          4 iterations
#    0.13057 iters/sec. Estimated time to finish: 0:00:07.658993.
# validation [##################################################] 100.00%
#          5 iterations
#    0.13134 iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [##########........................................] 20.00%
#          1 iterations
#    0.13434 iters/sec. Estimated time to finish: 0:00:29.775608.
# torch.Size([20, 5]) torch.Size([20])
# validation [####################..............................] 40.00%
#          2 iterations
#    0.13048 iters/sec. Estimated time to finish: 0:00:22.992648.
# torch.Size([20, 5]) torch.Size([20])
# validation [##############################....................] 60.00%
#          3 iterations
#    0.13054 iters/sec. Estimated time to finish: 0:00:15.320410.
# torch.Size([20, 5]) torch.Size([20])
# validation [########################################..........] 80.00%
#          4 iterations
#    0.13095 iters/sec. Estimated time to finish: 0:00:07.636235.
# 7           140         0.000345492  0.772285    0.809009    0.04        5116.19
# validation [##########........................................] 20.00%
#          1 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [####################..............................] 40.00%
#          2 iterations
#    0.12624 iters/sec. Estimated time to finish: 0:00:23.764822.
# validation [##############################....................] 60.00%
#          3 iterations
#    0.12375 iters/sec. Estimated time to finish: 0:00:16.161556.
# validation [########################################..........] 80.00%
#          4 iterations
#    0.12486 iters/sec. Estimated time to finish: 0:00:08.009051.
# validation [##################################################] 100.00%
#          5 iterations
#     0.1258 iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [##########........................................] 20.00%
#          1 iterations
#    0.12556 iters/sec. Estimated time to finish: 0:00:31.857795.
# torch.Size([20, 5]) torch.Size([20])
# validation [####################..............................] 40.00%
#          2 iterations
#    0.11892 iters/sec. Estimated time to finish: 0:00:25.227134.
# torch.Size([20, 5]) torch.Size([20])
# validation [##############################....................] 60.00%
#          3 iterations
#    0.11746 iters/sec. Estimated time to finish: 0:00:17.027724.
# torch.Size([20, 5]) torch.Size([20])
# validation [########################################..........] 80.00%
#          4 iterations
#    0.11735 iters/sec. Estimated time to finish: 0:00:08.521673.
# 8           160         0.000206107  0.723418    0.70258     0.03        5662.47
# validation [##########........................................] 20.00%
#          1 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [####################..............................] 40.00%
#          2 iterations
#    0.12578 iters/sec. Estimated time to finish: 0:00:23.851989.
# validation [##############################....................] 60.00%
#          3 iterations
#    0.12272 iters/sec. Estimated time to finish: 0:00:16.296629.
# validation [########################################..........] 80.00%
#          4 iterations
#    0.12226 iters/sec. Estimated time to finish: 0:00:08.179571.
# validation [##################################################] 100.00%
#          5 iterations
#    0.12237 iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [##########........................................] 20.00%
#          1 iterations
#    0.12353 iters/sec. Estimated time to finish: 0:00:32.381461.
# torch.Size([20, 5]) torch.Size([20])
# validation [####################..............................] 40.00%
#          2 iterations
#    0.12043 iters/sec. Estimated time to finish: 0:00:24.911732.
# torch.Size([20, 5]) torch.Size([20])
# validation [##############################....................] 60.00%
#          3 iterations
#    0.12081 iters/sec. Estimated time to finish: 0:00:16.554637.
# torch.Size([20, 5]) torch.Size([20])
# validation [########################################..........] 80.00%
#          4 iterations
#    0.12135 iters/sec. Estimated time to finish: 0:00:08.240819.
# 9           180         9.54915e-05  0.637886    0.779203    0.03        6232.68
# validation [##########........................................] 20.00%
#          1 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [####################..............................] 40.00%
#          2 iterations
#    0.13224 iters/sec. Estimated time to finish: 0:00:22.685856.
# validation [##############################....................] 60.00%
#          3 iterations
#    0.12923 iters/sec. Estimated time to finish: 0:00:15.476798.
# validation [########################################..........] 80.00%
#          4 iterations
#    0.12949 iters/sec. Estimated time to finish: 0:00:07.722380.
# validation [##################################################] 100.00%
#          5 iterations
#    0.13006 iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [##########........................................] 20.00%
#          1 iterations
#    0.13218 iters/sec. Estimated time to finish: 0:00:30.261812.
# torch.Size([20, 5]) torch.Size([20])
# validation [####################..............................] 40.00%
#          2 iterations
#    0.12933 iters/sec. Estimated time to finish: 0:00:23.195773.
# torch.Size([20, 5]) torch.Size([20])
# validation [##############################....................] 60.00%
#          3 iterations
#    0.12963 iters/sec. Estimated time to finish: 0:00:15.428306.
# torch.Size([20, 5]) torch.Size([20])
# validation [########################################..........] 80.00%
#          4 iterations
#    0.13022 iters/sec. Estimated time to finish: 0:00:07.679103.
# 10          200         2.44717e-05  0.562776    0.847217    0.04        6778.24
# validation [##########........................................] 20.00%
#          1 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [####################..............................] 40.00%
#          2 iterations
#    0.12342 iters/sec. Estimated time to finish: 0:00:24.307953.
# validation [##############################....................] 60.00%
#          3 iterations
#    0.12052 iters/sec. Estimated time to finish: 0:00:16.594271.
# validation [########################################..........] 80.00%
#          4 iterations
#    0.12089 iters/sec. Estimated time to finish: 0:00:08.272133.
# validation [##################################################] 100.00%
#          5 iterations
#    0.12152 iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [##########........................................] 20.00%
#          1 iterations
#    0.12669 iters/sec. Estimated time to finish: 0:00:31.573117.
# torch.Size([20, 5]) torch.Size([20])
# validation [####################..............................] 40.00%
#          2 iterations
#    0.12367 iters/sec. Estimated time to finish: 0:00:24.258855.
# torch.Size([20, 5]) torch.Size([20])
# validation [##############################....................] 60.00%
#          3 iterations
#    0.12395 iters/sec. Estimated time to finish: 0:00:16.135011.
# torch.Size([20, 5]) torch.Size([20])
# validation [########################################..........] 80.00%
#          4 iterations
#    0.12449 iters/sec. Estimated time to finish: 0:00:08.032460.
# 11          220         0           0.568148    0.671128    0.03        7336.28
# validation [##########........................................] 20.00%
#          1 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [####################..............................] 40.00%
#          2 iterations
#    0.13184 iters/sec. Estimated time to finish: 0:00:22.754349.
# validation [##############################....................] 60.00%
#          3 iterations
#     0.1276 iters/sec. Estimated time to finish: 0:00:15.673455.
# validation [########################################..........] 80.00%
#          4 iterations
#    0.12749 iters/sec. Estimated time to finish: 0:00:07.843801.
# validation [##################################################] 100.00%
#          5 iterations
#    0.12783 iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [##########........................................] 20.00%
#          1 iterations
#    0.12905 iters/sec. Estimated time to finish: 0:00:30.995364.
# torch.Size([20, 5]) torch.Size([20])
# validation [####################..............................] 40.00%
#          2 iterations
#    0.12657 iters/sec. Estimated time to finish: 0:00:23.701729.
# torch.Size([20, 5]) torch.Size([20])
# validation [##############################....................] 60.00%
#          3 iterations
#    0.12782 iters/sec. Estimated time to finish: 0:00:15.646873.
# torch.Size([20, 5]) torch.Size([20])
# validation [########################################..........] 80.00%
#          4 iterations
#    0.12887 iters/sec. Estimated time to finish: 0:00:07.759647.
# 12          240         2.44717e-05  0.534581    0.691862    0.03        7891.11
# validation [##########........................................] 20.00%
#          1 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [####################..............................] 40.00%
#          2 iterations
#    0.12681 iters/sec. Estimated time to finish: 0:00:23.656767.
# validation [##############################....................] 60.00%
#          3 iterations
#    0.12353 iters/sec. Estimated time to finish: 0:00:16.190292.
# validation [########################################..........] 80.00%
#          4 iterations
#    0.12406 iters/sec. Estimated time to finish: 0:00:08.060537.
# validation [##################################################] 100.00%
#          5 iterations
#    0.12519 iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [##########........................................] 20.00%
#          1 iterations
#     0.1326 iters/sec. Estimated time to finish: 0:00:30.165296.
# torch.Size([20, 5]) torch.Size([20])
# validation [####################..............................] 40.00%
#          2 iterations
#    0.13037 iters/sec. Estimated time to finish: 0:00:23.010713.
# torch.Size([20, 5]) torch.Size([20])
# validation [##############################....................] 60.00%
#          3 iterations
#    0.13105 iters/sec. Estimated time to finish: 0:00:15.260906.
# torch.Size([20, 5]) torch.Size([20])
# validation [########################################..........] 80.00%
#          4 iterations
#    0.13173 iters/sec. Estimated time to finish: 0:00:07.591159.
# 13          260         9.54915e-05  0.595392    0.750045    0.05        8430.27
# validation [##########........................................] 20.00%
#          1 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [####################..............................] 40.00%
#          2 iterations
#    0.13196 iters/sec. Estimated time to finish: 0:00:22.734215.
# validation [##############################....................] 60.00%
#          3 iterations
#    0.12879 iters/sec. Estimated time to finish: 0:00:15.528879.
# validation [########################################..........] 80.00%
#          4 iterations
#     0.1291 iters/sec. Estimated time to finish: 0:00:07.745876.
# validation [##################################################] 100.00%
#          5 iterations
#    0.12957 iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [##########........................................] 20.00%
#          1 iterations
#    0.13226 iters/sec. Estimated time to finish: 0:00:30.243972.
# torch.Size([20, 5]) torch.Size([20])
# validation [####################..............................] 40.00%
#          2 iterations
#     0.1293 iters/sec. Estimated time to finish: 0:00:23.201274.
# torch.Size([20, 5]) torch.Size([20])
# validation [##############################....................] 60.00%
#          3 iterations
#    0.12951 iters/sec. Estimated time to finish: 0:00:15.442550.
# torch.Size([20, 5]) torch.Size([20])
# validation [########################################..........] 80.00%
#          4 iterations
#    0.13009 iters/sec. Estimated time to finish: 0:00:07.687078.
# 14          280         0.000206107  0.57004     0.747924    0.05        8964.41
# validation [##########........................................] 20.00%
#          1 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [####################..............................] 40.00%
#          2 iterations
#    0.13217 iters/sec. Estimated time to finish: 0:00:22.698279.
# validation [##############################....................] 60.00%
#          3 iterations
#     0.1291 iters/sec. Estimated time to finish: 0:00:15.491583.
# validation [########################################..........] 80.00%
#          4 iterations
#       0.13 iters/sec. Estimated time to finish: 0:00:07.692464.
# validation [##################################################] 100.00%
#          5 iterations
#    0.13077 iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [##########........................................] 20.00%
#          1 iterations
#     0.1345 iters/sec. Estimated time to finish: 0:00:29.740469.
# torch.Size([20, 5]) torch.Size([20])
# validation [####################..............................] 40.00%
#          2 iterations
#    0.13051 iters/sec. Estimated time to finish: 0:00:22.986666.
# torch.Size([20, 5]) torch.Size([20])
# validation [##############################....................] 60.00%
#          3 iterations
#    0.13045 iters/sec. Estimated time to finish: 0:00:15.331400.
# torch.Size([20, 5]) torch.Size([20])
# validation [########################################..........] 80.00%
#          4 iterations
#    0.13087 iters/sec. Estimated time to finish: 0:00:07.640980.
# 15          300         0.000345492  0.557701    0.635577    0.04        9499.2
# validation [##########........................................] 20.00%
#          1 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [####################..............................] 40.00%
#          2 iterations
#    0.13205 iters/sec. Estimated time to finish: 0:00:22.718958.
# validation [##############################....................] 60.00%
#          3 iterations
#    0.12902 iters/sec. Estimated time to finish: 0:00:15.500908.
# validation [########################################..........] 80.00%
#          4 iterations
#    0.12908 iters/sec. Estimated time to finish: 0:00:07.747028.
# validation [##################################################] 100.00%
#          5 iterations
#    0.12975 iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [##########........................................] 20.00%
#          1 iterations
#    0.13363 iters/sec. Estimated time to finish: 0:00:29.934401.
# torch.Size([20, 5]) torch.Size([20])
# validation [####################..............................] 40.00%
#          2 iterations
#    0.13107 iters/sec. Estimated time to finish: 0:00:22.887785.
# torch.Size([20, 5]) torch.Size([20])
# validation [##############################....................] 60.00%
#          3 iterations
#    0.13142 iters/sec. Estimated time to finish: 0:00:15.218518.
# torch.Size([20, 5]) torch.Size([20])
# validation [########################################..........] 80.00%
#          4 iterations
#    0.13202 iters/sec. Estimated time to finish: 0:00:07.574829.
# 16          320         0.0005      0.670917    0.912797    0.05        10033.8
# validation [##########........................................] 20.00%
#          1 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [####################..............................] 40.00%
#          2 iterations
#    0.13211 iters/sec. Estimated time to finish: 0:00:22.708485.
# validation [##############################....................] 60.00%
#          3 iterations
#    0.12883 iters/sec. Estimated time to finish: 0:00:15.524392.
# validation [########################################..........] 80.00%
#          4 iterations
#    0.12922 iters/sec. Estimated time to finish: 0:00:07.738535.
# validation [##################################################] 100.00%
#          5 iterations
#    0.12985 iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [##########........................................] 20.00%
#          1 iterations
#    0.13436 iters/sec. Estimated time to finish: 0:00:29.770460.
# torch.Size([20, 5]) torch.Size([20])
# validation [####################..............................] 40.00%
#          2 iterations
#     0.1315 iters/sec. Estimated time to finish: 0:00:22.814512.
# torch.Size([20, 5]) torch.Size([20])
# validation [##############################....................] 60.00%
#          3 iterations
#    0.13192 iters/sec. Estimated time to finish: 0:00:15.161068.
# torch.Size([20, 5]) torch.Size([20])
# validation [########################################..........] 80.00%
#          4 iterations
#    0.13218 iters/sec. Estimated time to finish: 0:00:07.565655.
# 17          340         0.000654508  0.684965    1.63517     0.05        10567.3
# validation [##########........................................] 20.00%
#          1 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [####################..............................] 40.00%
#          2 iterations
#    0.13237 iters/sec. Estimated time to finish: 0:00:22.663230.
# validation [##############################....................] 60.00%
#          3 iterations
#    0.12911 iters/sec. Estimated time to finish: 0:00:15.490462.
# validation [########################################..........] 80.00%
#          4 iterations
#    0.12933 iters/sec. Estimated time to finish: 0:00:07.732385.
# validation [##################################################] 100.00%
#          5 iterations
#    0.12977 iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [##########........................................] 20.00%
#          1 iterations
#    0.13238 iters/sec. Estimated time to finish: 0:00:30.215096.
# torch.Size([20, 5]) torch.Size([20])
# validation [####################..............................] 40.00%
#          2 iterations
#    0.12947 iters/sec. Estimated time to finish: 0:00:23.170854.
# torch.Size([20, 5]) torch.Size([20])
# validation [##############################....................] 60.00%
#          3 iterations
#    0.12976 iters/sec. Estimated time to finish: 0:00:15.412680.
# torch.Size([20, 5]) torch.Size([20])
# validation [########################################..........] 80.00%
#          4 iterations
#    0.13014 iters/sec. Estimated time to finish: 0:00:07.683868.
# 18          360         0.000793893  0.759689    0.784223    0.04        11103.2
# validation [##########........................................] 20.00%
#          1 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [####################..............................] 40.00%
#          2 iterations
#     0.1323 iters/sec. Estimated time to finish: 0:00:22.676370.
# validation [##############################....................] 60.00%
#          3 iterations
#    0.12916 iters/sec. Estimated time to finish: 0:00:15.484519.
# validation [########################################..........] 80.00%
#          4 iterations
#    0.12916 iters/sec. Estimated time to finish: 0:00:07.742266.
# validation [##################################################] 100.00%
#          5 iterations
#    0.12953 iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [##########........................................] 20.00%
#          1 iterations
#    0.13129 iters/sec. Estimated time to finish: 0:00:30.466651.
# torch.Size([20, 5]) torch.Size([20])
# validation [####################..............................] 40.00%
#          2 iterations
#    0.12868 iters/sec. Estimated time to finish: 0:00:23.312743.
# torch.Size([20, 5]) torch.Size([20])
# validation [##############################....................] 60.00%
#          3 iterations
#    0.12926 iters/sec. Estimated time to finish: 0:00:15.473017.
# torch.Size([20, 5]) torch.Size([20])
# validation [########################################..........] 80.00%
#          4 iterations
#     0.1298 iters/sec. Estimated time to finish: 0:00:07.703995.
# 19          380         0.000904508  0.7765      1.29234     0.05        11638.4
# validation [##########........................................] 20.00%
#          1 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [####################..............................] 40.00%
#          2 iterations
#    0.13067 iters/sec. Estimated time to finish: 0:00:22.957779.
# validation [##############################....................] 60.00%
#          3 iterations
#    0.12771 iters/sec. Estimated time to finish: 0:00:15.660076.
# validation [########################################..........] 80.00%
#          4 iterations
#    0.12845 iters/sec. Estimated time to finish: 0:00:07.785006.
# validation [##################################################] 100.00%
#          5 iterations
#    0.12907 iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# torch.Size([20, 5]) torch.Size([20])
# validation [##########........................................] 20.00%
#          1 iterations
#    0.13204 iters/sec. Estimated time to finish: 0:00:30.293820.
# torch.Size([20, 5]) torch.Size([20])
# validation [####################..............................] 40.00%
#          2 iterations
#    0.13008 iters/sec. Estimated time to finish: 0:00:23.062136.
# torch.Size([20, 5]) torch.Size([20])
# validation [##############################....................] 60.00%
#          3 iterations
#    0.13058 iters/sec. Estimated time to finish: 0:00:15.316578.
# torch.Size([20, 5]) torch.Size([20])
# validation [########################################..........] 80.00%
#          4 iterations
#    0.13136 iters/sec. Estimated time to finish: 0:00:07.612649.
# 20          400         0.000975528  0.755366    1.90254     0.03        12174.3
