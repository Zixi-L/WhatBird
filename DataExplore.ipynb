# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('train.csv')
df.head(2).T
# Out:
#                                                                   0  \
# rating                                                          3.5
# playback_used                                                    no
# ebird_code                                                   aldfly
# channels                                                   1 (mono)
# date                                                     2013-05-25
# pitch                                                 Not specified
# duration                                                         25
# filename                                               XC134874.mp3
# speed                                                 Not specified
# species                                            Alder Flycatcher
# number_of_notes                                       Not specified
# title                 XC134874 Alder Flycatcher (Empidonax alnorum)
# secondary_labels  ['Empidonax minimus_Least Flycatcher', 'Leioth...
# ...

# %%
# about half of the labels has 100 files/record
birds = df['ebird_code'].value_counts()
plt.plot(birds)

# %% [markdown]
# ## Our choices are: bulori,wilfly, bkcchi, bluejay

# %%
df_bulori = df[df['ebird_code']=='bulori']
df_bulori.count()
# Out:
# rating              100
# playback_used        94
# ebird_code          100
# channels            100
# date                100
# pitch               100
# duration            100
# filename            100
# speed               100
# species             100
# number_of_notes     100
# title               100
# secondary_labels    100
# bird_seen            94
# sci_name            100
# location            100
# latitude            100
# sampling_rate       100
# type                100
# elevation           100
# description          81
# bitrate_of_mp3      100
# file_type           100
# volume              100
# background           78
# xc_id               100
# url                 100
# country             100
# author              100
# primary_label       100
# longitude           100
# length              100
# time                100
# recordist           100
# license             100
# dtype: int64

# %%
df_wilfly = df[df['ebird_code']=='wilfly']
df_wilfly.count()
# Out:
# rating              100
# playback_used        95
# ebird_code          100
# channels            100
# date                100
# pitch               100
# duration            100
# filename            100
# speed               100
# species             100
# number_of_notes     100
# title               100
# secondary_labels    100
# bird_seen            95
# sci_name            100
# location            100
# latitude            100
# sampling_rate       100
# type                100
# elevation           100
# description          68
# bitrate_of_mp3      100
# file_type           100
# volume              100
# background           61
# xc_id               100
# url                 100
# country             100
# author              100
# primary_label       100
# longitude           100
# length              100
# time                100
# recordist           100
# license             100
# dtype: int64

# %%
df_bkcchi = df[df['ebird_code']=='bkcchi']
df_bkcchi.count()
# Out:
# rating              100
# playback_used        90
# ebird_code          100
# channels            100
# date                100
# pitch               100
# duration            100
# filename            100
# speed               100
# species             100
# number_of_notes     100
# title               100
# secondary_labels    100
# bird_seen            90
# sci_name            100
# location            100
# latitude            100
# sampling_rate       100
# type                100
# elevation           100
# description          71
# bitrate_of_mp3      100
# file_type           100
# volume              100
# background           35
# xc_id               100
# url                 100
# country             100
# author              100
# primary_label       100
# longitude           100
# length              100
# time                100
# recordist           100
# license             100
# dtype: int64

# %%
df_blujay = df[df['ebird_code']=='blujay']
df_blujay.count()
# Out:
# rating              100
# playback_used        92
# ebird_code          100
# channels            100
# date                100
# pitch               100
# duration            100
# filename            100
# speed               100
# species             100
# number_of_notes     100
# title               100
# secondary_labels    100
# bird_seen            92
# sci_name            100
# location            100
# latitude            100
# sampling_rate       100
# type                100
# elevation           100
# description          78
# bitrate_of_mp3      100
# file_type           100
# volume              100
# background           36
# xc_id               100
# url                 100
# country             100
# author              100
# primary_label       100
# longitude           100
# length              100
# time                100
# recordist           100
# license             100
# dtype: int64

# %%
df_chispa = df[df['ebird_code']=='chispa']
df_chispa.count()
# Out:
# rating              100
# playback_used        93
# ebird_code          100
# channels            100
# date                100
# pitch               100
# duration            100
# filename            100
# speed               100
# species             100
# number_of_notes     100
# title               100
# secondary_labels    100
# bird_seen            93
# sci_name            100
# location            100
# latitude            100
# sampling_rate       100
# type                100
# elevation           100
# description          70
# bitrate_of_mp3      100
# file_type           100
# volume              100
# background           30
# xc_id               100
# url                 100
# country             100
# author              100
# primary_label       100
# longitude           100
# length              100
# time                100
# recordist           100
# license             100
# dtype: int64
